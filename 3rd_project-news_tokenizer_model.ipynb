# %% [markdown]
# # 크롤링한 뉴스 모델 성능 높이기

# %% [markdown]
# ## Mecab으로 토큰화하기

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
import os
from konlpy.tag import Mecab
tokenizer = Mecab()

# %%
csv_path = os.getenv("HOME") + "/aiffel/news_crawler/news_data.csv"
df = pd.read_table(csv_path, sep=',')
df.head()
df['news'] = df['news'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
df['news']
df.drop_duplicates(subset=['news'], inplace=True)
print(df.groupby('code').size().reset_index(name = 'count'))
# Out:
#     code  count
# 0  IT/과학    903
# 1     사회   1668
# 2  생활/문화   1423

# %%
stopwords = ['에','는','은','을','했','에게','있','이','의','하','한','다','과','때문','할','수','무단','따른','및','금지','전재','경향신문','기자','는데','가','등','들','파이낸셜','저작','등','뉴스']

# %%
def preprocessing(data):
  text_data = []

  for sentence in data:
    temp_data = []
    #- 토큰화
    temp_data = tokenizer.morphs(sentence) 
    #- 불용어 제거
    temp_data = [word for word in temp_data if not word in stopwords] 
    text_data.append(temp_data)

  text_data = list(map(' '.join, text_data))

  return text_data

# %%
import time
start = time.time()
text_data = preprocessing(df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 주 시 일 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 주 시민 받 긴급 재난 지원금 인 이상 가구 기준 으로 만 원 받 게 되 며 인 가구 만 원 인 가구 만 원 인 가구 만 원 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 다른 이유 국비 지방비 부담 비율 다파 주 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 원 지급 고 어 시민 국비 지원금 만 지급 며 인 가구 기준 으로 총 지원 금액 파주시 재난 기본소득 만 원 경기도 재난 기본소득 만 원 정부 긴급 재난 지원금 만 원 총 만 원 받 게 된다 취약 계층 아닌 시민 오 월일 부터 소지 고 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 주 시 일 김정기 부시장 단장 으로 긴급 재난 지원금 추진 태 스 크 포스 를 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자 재 배포
# time : 4.940153121948242

# %%
X_train, X_test, y_train, y_test = train_test_split(text_data, df['code'], random_state = 0)

# %%
print('훈련용 뉴스 기사의 개수 :', len(X_train))
print('테스트용 뉴스 기사의 개수 : ', len(X_test))
print('훈련용 레이블의 개수 : ', len(y_train))
print('테스트용 레이블의 개수 : ', len(y_test))
# Out:
# 훈련용 뉴스 기사의 개수 : 2995
# 테스트용 뉴스 기사의 개수 :  999
# 훈련용 레이블의 개수 :  2995
# 테스트용 레이블의 개수 :  999

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
def tfidf_vectorizer(data):
  data_counts = count_vect.transform(data)
  data_tfidf = tfidf_transformer.transform(data_counts)
  return data_tfidf

# %%
y_pred= clf.predict(tfidf_vectorizer(X_test))
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.90      0.74      0.81       236
#           사회       0.79      0.91      0.85       422
#        생활/문화       0.81      0.76      0.79       341
#
#     accuracy                           0.82       999
#    macro avg       0.83      0.80      0.81       999
# weighted avg       0.82      0.82      0.82       999

# %% [markdown]
# ### Mecab의 장점은 가장 빠른 시간을 기록했다는 것에 있다. 다른 형태소 분석기는 1분을 넘긴 것에 비해 Mecab은 4초밖에 걸리지 않았다. 그렇지만 정확도에서 82%를 기록하고 가중평균 f1-score도 82%를 유지한다. 종합 결과를 볼때 Mecab이 가장 적합한 형태소분석기라고 생각한다.

# %% [markdown]
# ---

# %% [markdown]
# ## Hannanum으로 토큰화하기

# %%
from konlpy import init_jvm 
from konlpy.tag import Hannanum 
init_jvm() 
hannanum = Hannanum()

# %%
def preprocessing_hannanum(data):
  text_data = []

  for sentence in data:
    temp_data = []
    #- 토큰화
    temp_data = hannanum.morphs(sentence) 
    #- 불용어 제거
    temp_data = [word for word in temp_data if not word in stopwords] 
    text_data.append(temp_data)

  text_data = list(map(' '.join, text_data))

  return text_data

# %%
import time
start = time.time()
text_data2 = preprocessing_hannanum(df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 주 시 일 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 주 시민 받 긴급 재난 지원금 인 이상 가구 기준 으로 만 원 받 게 되 며 인 가구 만 원 인 가구 만 원 인 가구 만 원 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 다른 이유 국비 지방비 부담 비율 다파 주 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 원 지급 고 어 시민 국비 지원금 만 지급 며 인 가구 기준 으로 총 지원 금액 파주시 재난 기본소득 만 원 경기도 재난 기본소득 만 원 정부 긴급 재난 지원금 만 원 총 만 원 받 게 된다 취약 계층 아닌 시민 오 월일 부터 소지 고 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 주 시 일 김정기 부시장 단장 으로 긴급 재난 지원금 추진 태 스 크 포스 를 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자 재 배포
# time : 154.8171546459198

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(text_data2, df['code'], random_state = 0)

# %%
count_vect = CountVectorizer()
X_train_2_counts = count_vect.fit_transform(X_train_2)

tfidf_transformer = TfidfTransformer()
X_train_2_tfidf = tfidf_transformer.fit_transform(X_train_2_counts)

clf = MultinomialNB().fit(X_train_2_tfidf, y_train_2)

# %%
def tfidf_vectorizer(data):
  data_counts = count_vect.transform(data)
  data_tfidf = tfidf_transformer.transform(data_counts)
  return data_tfidf

# %%
y_pred_2 = clf.predict(tfidf_vectorizer(X_test_2))
print(metrics.classification_report(y_test_2, y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.90      0.64      0.75       236
#           사회       0.79      0.91      0.85       422
#        생활/문화       0.79      0.79      0.79       341
#
#     accuracy                           0.81       999
#    macro avg       0.83      0.78      0.80       999
# weighted avg       0.82      0.81      0.81       999

# %% [markdown]
# ### Hannanum같은 경우 154초라는 시간이 결렸지만 정확도는 81%, 가중평균 f1-score로 오히려 Mecab에 밀린다. 실험 결과에서 Hannanum은 가장 최적화된 형태소분석기라고 보기 어렵다.

# %% [markdown]
# ---

# %% [markdown]
# ## kkma으로 토큰화하기

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
def preprocessing_kkma(data):
  text_data = []

  for sentence in data:
    temp_data = []
    #- 토큰화
    temp_data = kkma.morphs(sentence) 
    #- 불용어 제거
    temp_data = [word for word in temp_data if not word in stopwords] 
    text_data.append(temp_data)

  text_data = list(map(' '.join, text_data))

  return text_data

# %%
import time
start = time.time()
text_data3 = preprocessing_kkma(df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 주 시 일 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 주 시민 받 긴급 재난 지원금 인 이상 가구 기준 으로 만 원 받 게 되 며 인 가구 만 원 인 가구 만 원 인 가구 만 원 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 다른 이유 국비 지방비 부담 비율 다파 주 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 원 지급 고 어 시민 국비 지원금 만 지급 며 인 가구 기준 으로 총 지원 금액 파주시 재난 기본소득 만 원 경기도 재난 기본소득 만 원 정부 긴급 재난 지원금 만 원 총 만 원 받 게 된다 취약 계층 아닌 시민 오 월일 부터 소지 고 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 주 시 일 김정기 부시장 단장 으로 긴급 재난 지원금 추진 태 스 크 포스 를 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자 재 배포
# time : 1098.8279449939728

# %%
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(text_data3, df['code'], random_state = 0)

# %%
count_vect = CountVectorizer()
X_train_3_counts = count_vect.fit_transform(X_train_3)

tfidf_transformer = TfidfTransformer()
X_train_3_tfidf = tfidf_transformer.fit_transform(X_train_3_counts)

clf = MultinomialNB().fit(X_train_3_tfidf, y_train_3)

# %%
y_pred_3 = clf.predict(tfidf_vectorizer(X_test_3))
print(metrics.classification_report(y_test_3, y_pred_3))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.90      0.75      0.82       236
#           사회       0.80      0.91      0.85       422
#        생활/문화       0.81      0.77      0.79       341
#
#     accuracy                           0.82       999
#    macro avg       0.84      0.81      0.82       999
# weighted avg       0.83      0.82      0.82       999

# %% [markdown]
# ### Kkma 형태소 분석기의 성능은 정확도 82%, 가중평균 f1-score 82%라서 Mecab과 동등한 성능을 보여주지만 1098초 (18.3분)이라는 어마어마한 시간이 걸린다. 그렇기에 효율성이라는 측면에서 Kkma형태소 분석기는 좋지 않다고 생각한다.

# %% [markdown]
# ---

# %% [markdown]
# ## Komoran으로 토큰화하기

# %%
from konlpy.tag import Komoran
komoran = Komoran()

# %%
def preprocessing_komoran(data):
  text_data = []

  for sentence in data:
    temp_data = []
    #- 토큰화
    temp_data = komoran.morphs(sentence) 
    #- 불용어 제거
    temp_data = [word for word in temp_data if not word in stopwords] 
    text_data.append(temp_data)

  text_data = list(map(' '.join, text_data))

  return text_data

# %%
import time
start = time.time()
text_data4 = preprocessing_komoran(df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 주 시 일 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 주 시민 받 긴급 재난 지원금 인 이상 가구 기준 으로 만 원 받 게 되 며 인 가구 만 원 인 가구 만 원 인 가구 만 원 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 다른 이유 국비 지방비 부담 비율 다파 주 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 원 지급 고 어 시민 국비 지원금 만 지급 며 인 가구 기준 으로 총 지원 금액 파주시 재난 기본소득 만 원 경기도 재난 기본소득 만 원 정부 긴급 재난 지원금 만 원 총 만 원 받 게 된다 취약 계층 아닌 시민 오 월일 부터 소지 고 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 주 시 일 김정기 부시장 단장 으로 긴급 재난 지원금 추진 태 스 크 포스 를 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자 재 배포
# time : 62.95089364051819

# %%
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(text_data4, df['code'], random_state = 0)

# %%
count_vect = CountVectorizer()
X_train_4_counts = count_vect.fit_transform(X_train_4)

tfidf_transformer = TfidfTransformer()
X_train_4_tfidf = tfidf_transformer.fit_transform(X_train_4_counts)

clf = MultinomialNB().fit(X_train_4_tfidf, y_train_4)

# %%
y_pred_4 = clf.predict(tfidf_vectorizer(X_test_4))
print(metrics.classification_report(y_test_4, y_pred_4))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.90      0.74      0.81       236
#           사회       0.80      0.91      0.85       422
#        생활/문화       0.81      0.77      0.79       341
#
#     accuracy                           0.82       999
#    macro avg       0.83      0.81      0.82       999
# weighted avg       0.83      0.82      0.82       999

# %% [markdown]
# ### Komoran 형태소 분석기는 정확도는 82%, 가중 f1-score도 82%로 Mecab이랑 동등한 결과를 나타냈지만 시간이 62초가 걸려 상대적으로 Mecab이 더 좋은 형태소 분석기라 볼 수 있다.

# %% [markdown]
# ---

# %% [markdown]
# ## Twitter 형태소 분석기

# %%
from konlpy.tag import Twitter
twitter = Twitter()
# Out:
# /home/aiffel0038/anaconda3/envs/aiffel/lib/python3.7/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
def preprocessing_twitter(data):
  text_data = []

  for sentence in data:
    temp_data = []
    #- 토큰화
    temp_data = twitter.morphs(sentence) 
    #- 불용어 제거
    temp_data = [word for word in temp_data if not word in stopwords] 
    text_data.append(temp_data)

  text_data = list(map(' '.join, text_data))

  return text_data

# %%
import time
start = time.time()
text_data5 = preprocessing_twitter(df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 주 시 일 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 주 시민 받 긴급 재난 지원금 인 이상 가구 기준 으로 만 원 받 게 되 며 인 가구 만 원 인 가구 만 원 인 가구 만 원 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 다른 이유 국비 지방비 부담 비율 다파 주 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 원 지급 고 어 시민 국비 지원금 만 지급 며 인 가구 기준 으로 총 지원 금액 파주시 재난 기본소득 만 원 경기도 재난 기본소득 만 원 정부 긴급 재난 지원금 만 원 총 만 원 받 게 된다 취약 계층 아닌 시민 오 월일 부터 소지 고 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 주 시 일 김정기 부시장 단장 으로 긴급 재난 지원금 추진 태 스 크 포스 를 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자 재 배포
# time : 141.47270035743713

# %%
X_train_5, X_test_5, y_train_5, y_test_5 = train_test_split(text_data5, df['code'], random_state = 0)

# %%
count_vect = CountVectorizer()
X_train_5_counts = count_vect.fit_transform(X_train_5)

tfidf_transformer = TfidfTransformer()
X_train_5_tfidf = tfidf_transformer.fit_transform(X_train_5_counts)

clf = MultinomialNB().fit(X_train_5_tfidf, y_train_5)

# %%
y_pred_5 = clf.predict(tfidf_vectorizer(X_test_5))
print(metrics.classification_report(y_test_5, y_pred_5))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.91      0.70      0.79       236
#           사회       0.78      0.93      0.85       422
#        생활/문화       0.83      0.76      0.79       341
#
#     accuracy                           0.82       999
#    macro avg       0.84      0.80      0.81       999
# weighted avg       0.83      0.82      0.82       999

# %% [markdown]
# ### Twitter 분석기는 정확도나 가중평균은 Mecab과 동일하지만 시간에서 141초가 걸려 Mecab보다 좋은 형태소 분석기라고 보기 어렵다.

# %% [markdown]
# ---

# %% [markdown]
# ## 불용어 추가하기

# %%
text_data
# Out:
# ['파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 시 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 시민 긴급 재난 지원금 인 이상 가구 기준 만 게 며 인 가구 만 인 가구 만 인 가구 만 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 이유 국비 지방비 부담 비율 다파 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 지급 어 시민 국비 지원금 만 지급 며 인 가구 기준 총 지원 금액 파주시 재난 기본소득 만 경기도 재난 기본소득 만 정부 긴급 재난 지원금 만 총 만 게 된다 취약 계층 아닌 시민 월일 부터 소지 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 시 김정기 부시장 단장 긴급 재난 지원금 추진 태 스 포스 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자',
#  '동영상 천 물류 창고 화재 발화 지점 지목 된 지하 층 에서 산소 절단기 산소 공급 호스 끊어진 채 발견 돼 경찰 폭발 가능 성 수사 습니다 확보 현장 감식 사진 면 산소 절단기 연결 된 산소 공급 호스 날카롭 게 절단 돼 었 습니다 전문가 산소 공급 호스 기계 충격 의해 절단 됐 실제 산소 샜 다면 폭발 일어날 다는 의견 제시 습니다 지하 층 에선 밖 전동 절단기 그라인더 불꽃 발생 시킬 작업 도구 다수 나와 경찰 집중 분석 습니다 경찰 건물 옆 에서 우레탄 혼합 해 작업 현장 보내 차량 발견 해 화재 당시 우레탄 폼 발포 작업 함께 불꽃 튀 화기 작업 동시 진행 됐 는지 조사 습니다 당신 제보 됩니다 여러분 소중 제보 기다립니다 검색 해 채널 추가 전화 메일 온라인 제보 권 자',
#  '황범 순 의정부 시 부시장 지대 학교 의정부 캠퍼스 부속 병원 공사 현장 안전 점검 사진 제공 정 부시 황범 순 의정부 시 부시장 지대 학교 의정부 캠퍼스 부속 병원 공사 현장 안전 점검 사진 제공 정 부시 황범 순 의정부 시 부시장 지대 학교 의정부 캠퍼스 부속 병원 공사 현장 안전 점검 사진 제공 정 부시 황범 순 의정부 시 부시장 지대 학교 의정부 캠퍼스 부속 병원 공사 현장 안전 점검 사진 제공 정부 시 정부 강근주 황범 순 의정부 시 부시장 시공 인 을지 대학교 의정부 캠퍼스 부속 병원 공사 현장 방문 해 긴급 안전 점검 진행 이번 긴급 점검 월일 경기도 이천시 물류 창고 신축 공사장 화재 참사 관련 해 의정부 유사 사례 발생 도록 사전 대비 차원 에서 이뤄졌 특히 의정부 소방서 고용 노동청 의정부 지청 동행 해 소방법 산업 보건 법 준수 여부 공사 전반 인 추진 상황 점검 합동 점검 반 우레탄 폼 발포 용접 금속 류 절단 화재 발생 빈도 높 작업 대한 소방 안전 관리 밀폐 된 공간 화제 위험 요소 임시 소방 시설 설치 환경 의무 사항 이행 여부 집중 살펴봤 황범 순 부시장 현장 관계자 노고 격려 며 항상 경각심 갖 화재 재난 예방 만전 해 달 라며 코 관련 해 건설 현장 종사자 간 거리 두기 방역 지침 준 해 달 요청 권 자',
#  '귀갓길 여성 쫓아가 성범죄 시도 대 남성 구속 됐 습니다 서울 강남 경찰서 강 간상 해 혐의 대 구속 해 수사 오늘 밝혔 습니다 지난달 새벽 서울 강남구 에서 귀가 던 피해 여성 근처 지하철역 에서부터 따라가 성폭행 시도 려다 도망간 혐의 습니다 피해 여성 신고 주변 수색 던 경찰 붙잡혔 습니다 과정 에서 피해 여성 경미 부상 입 전해졌 습니다 경찰 상대 범행 경위 추가 조사 뒤 조만간 검찰 넘길 방침 입니다 안희재 복제',
#  '서울 연합뉴스 대한 약사회 부터 코로나 바이러스 감염증 대응 체계 거리 두기 에서 생활 거리 전환 함 대국민 안내문 발표 대한 약사회 황사 미세먼지 차단 효과 구분 라며 코 침방울 통한 감염 전파 상황 에서 효과 큰 차이 밝혔 다이어 코로나 감염 환자 돌보 보호자 의료진 아닌 일반인 보건 용 마스크 착용 사용 감염 예방 목적 충분히 달성 오히려 호흡 쉬워 장시간 착용 시 적합 덧붙였 사진 생활 거리 전환 대국민 안내 포스터 대한 약사회 제공 재판매',
#  '질서 정연 코로나 확산 방지 위한 물리 거리 두기 생활 거리 전환 된 첫날 인 서울 용산구 국립 중앙 박물관 에서 관람객 거리 두기 며 입장 국립 중앙 박물관 사전 예약 해야 입장 가능 며 당 인원 제한 한다 김기남 질서 정연 코로나 확산 방지 위한 물리 거리 두기 생활 거리 전환 된 첫날 인 서울 용산구 국립 중앙 박물관 에서 관람객 거리 두기 며 입장 국립 중앙 박물관 사전 예약 해야 입장 가능 며 당 인원 제한 한다 김기남 물리 거리 두기 생활 거리 전환 된 첫날 인 지하철 사무실 쇼핑몰 좁 공간 빽빽이 들어차 거나 마스크 쓰 모습 곳곳 에서 눈 띄 었 서울 마포구 에서 직장 인 이모 출근 지하철 평소 처럼 다닥다닥 붙 어서 야 다며 회사 사무실 배치 여전히 닭장 처럼 빼곡 해 거리 불 가능 직장 인 박모 사무실 마스크 쓴 다며 인사 팀 직원 방역 책임자 지정 된 공지 메일 수시로 보내 지만 마스크 쓴다고 지적 중앙 재난 안전 대책 본부 대본 지난 내놓 생활 거리 두기 세부 지침 면 사무실 에서 최소 이상 거리 두기 해야 며 실내 다중 이용 시설 이용 시 마스크 착용 해야 한다 직장 방역 관리자 매일 노동자 체온 검사 방역 지침 지키 는지 확인 해야 한다 하지만 지침 지켜 주부 이모 쇼핑몰 야외 어린이 놀이 시설 갔 너무 마스크 쓴 어린이 볼일 포기 그냥 돌아왔 정부 발표 생활 거리 두기 지침 게 개인 방역 대 지침 보조 수칙 집단 방역 대 핵심 수칙 세부 지침 구성 돼 장례식장 에서 조문객 맞 악수 보다 목례 인사 라는 구체 내용 명시 지만 반면 독일 방역 당국 코로나 확산 방지 지난 월일 문 닫 았 던 미용실 최근 열기 면서 내놓 세부 지침 매우 구체 다독일 방역 당국 지침 면 대기 손 님 가득 차 피하 미용실 무조건 예약 제 운영 해야 한다 비말 전파 막 헤어드라이어 사용 최소 화 머리 스타일 대한 논의 거울 통해 떨어져 돼 김강립 중대 본 총괄 조정관 세부 지침 계속 추가 보완 겠 다며 현재 에서 까지 늘리 추가 검토 생활 방역 위원회 논의 거쳐 쯤 개정판 발표 겠 설명 정부 생활 거리 두기 지침 반드시 지켜야 사항 대해서 국회 논의 통해 법제 화 방안 고려 하지만 추가 수칙 발표 국회 법제 화 까지 최소 달 걸리 셈 김창엽 서울대 보건 대학원 교수 시민 건강 연구소 소장 세부 지침 계속 추가 필요 지만 각 사업장 에서 지침 실제로 적용 도록 조언 점검 지원 시스템 빨리 만드 중요 지적 물리 거리 두기 기간 동안 구청 운영 자제 권고 내려진 시설 수시로 점검 개선 사항 내놓 처럼 생활 거리 또한 지원 체계 마련 필요 다는 김 교수 직장 방역 노조 직원 목소리 반영 어려운 회사 현실 텐데 노동자 목소리 최대한 반영 해야 현실 성 실행 방안 나올 덧붙였 이혜인',
#  '코로나 걸렸 친구 아무래도 멀리 게 될 아요 재발 가능 성 요 누가 기침 만 해도 쟤 코로나다 놀리 거나 코로나 왕따 당하 학생 생길 어요 올해 고등학교 진학 모양 등교 시작 면 아무래도 보단 예민 상태 학교 다닐 다며 같이 이양 뿐 만 등교 개학 시작 약 주일 앞두 학생 사이 에선 코로나 왕따 우려 번지 이날 사회관 계망 서비스 에선 등교 개학 문제점 란 게 시물 공유 여기 이동 수업 이나 급식 감염 우려 뿐 라 따돌림 항목 포함 돼 선풍기 이용 화장실 무조건 참 아야 함 일부 내용 부 정확 정보 바탕 작성 된 지만 코로나 왕따 코로나 환자 대한 낙인 배제 학교 에서 발생 다는 현실 인 우려 구체 천식 감기 학생 기침 면 시선 쏠릴 개학 코 걸려서 전염 면 왕따 가능 성 음 담겼 특히 천식 호흡기 기저 질환 앓 학생 누구 보다 걱정 모양 오랜만 등교 앞두 조금 설렌다 온라인 수업 보다 직접 수업 듣 게 이해 된다면서 천식 어 기침 조절 기침 면 친구 시선 우려 역시 천식 김모양 호흡 곤란 자주 와서 장시간 마스크 쓰 면 답답 어지러운 잔기침 쏠리 시선 불편 사실상 새 학기 시작 이나 마찬가지 인 등교 개학 이후 어떻게 새 친구 사귀 어야 할지 고민거리 모양 코로나 언제 어디 서 걸리 는지 학교 모여 면 의심 환자 될까 우려 된다 선생 님 말씀 듣 코 옮긴다고 장난치 애 을까 걱정 김서영 박채영',
#  '메이저 리그 다저스 시즌 마지막 경기 였 신인 타자 더스티 베이커 현 휴스턴 애 스트로스 감독 휴스턴 경기 에서 시즌 호 홈런 때렸 다저스 사상 처음 홈런 타자 배출 순간 었 기념비 인 홈런 치 홈 들어오 베이커 신인 동료 글렌 버크 기다리 었 버크 오른손 번쩍 었 돌아오 던 베이커 오른손 함께 어 짝 마주쳤 역사 인 하이파이브 탄생 순간 었 이후 스포츠 에서 하이파이브 성공 인 플레이 대한 축하 세리 머니 자리 잡 았 남녀 스포츠 가리 손 마주치 장면 함께 라는 의미 더한다 만화 강백호 서태웅 하이파이브 장면 주인공 마음 한뜻 뭉쳤 다는 상징 보여 며 팬 가슴 박혔 하지만 코로나 하이파이브 멸종 가져왔 포스트 코로나 시대 에서 맨 손 접촉 금기시 된다 지난 개막 프로 야구 리그 코로나 대응 매뉴얼 하이파이브 명문화 홈런 치 들어올 주루 코치 홈 에서 기다리 동료 자연스레 나누 하이파이브 탄생 처럼 야구 상징 장면 지만 이상 어렵 코로나 바이러스 절멸 선언 더라도 맨손 접촉 트라우마 생기 상황 에서 하이파이브 역사 만 남 가능 성 높 뉴욕 타임스 스포츠 상징 행위 인 하이파이브 사라질 전했 하이파이브 함께 버락 오바마 미국 대통령 시그 니 처 동작 던 주먹 맞대 사라질 위기 놓였 경기 페어플레이 다짐 각종 행사 사라진다 축구 농구 배구 코트 반 나눠 쓰 대부분 구기 종목 경기 전후 하프 라인 모여 악수 나누 기본 었 대신 팔꿈치 맞부딪치 대안 지만 바라보 느낌 감동 예전 사뭇 다르 하이파이브 멸종 보다 팬 더욱 슬프 게 건 선수 대한 사인 요청 코로나 초기 잉글랜드 프리미어 리그 리버풀 위르겐 클롭 감독 경기장 들어갈 팬 손 내밀 자 손 치워 강하 게 거부 당시 까지 만 해도 팬 로부터 펜 건네 행위 수준 었 지만 이후 아예 이내 접근 명문화 됐 사 인 요청 위한 접근 원천 봉쇄 된다 리그 롯데 고가 유니폼 구매 고객 대상 사인 대신 드립니다 이벤트 벌이 지만 기다렸 다가 만 사인 직접 의미 상당히 다르 리그 구단 관계자 코로나 이후 보다 전한 사인 문화 위한 검토 필요 이용균',
#  '교수 업 앞둔 경북 학교 보건 실에 손 소독 제 마스크 방역 물품 상자 째 쌓여 여러 차례 연기 됐 던 만큼 학교 에서 모의 훈련 까지 면서 등교 수업 준비 지만 코로나 완전히 종식 된 교사 학부모 여전히 안심 어려운 상황 교사 ㄱ 학생 여명 중학교 에서 근무 한다 이날 동료 교사 회의 며 눈 띄 문제점 씩 해결 해 나갔 지만 학생 방역 지침 따라줄지 걱정 ㄱ 학생 마스크 계속 쓰 을지 마스크 까먹 가져오 학생 텐데 학교 에서 마스크 충분히 나눠 줄 을지 염려 된다고 코로나 늘어난 방역 업무 나눠 맡 배 정옥 교사 전국 보건 교사 노조 위원장 근무 학교 보건 실 옆 운영 회의실 일시 관찰 실로 지정 증상 학생 학생 분리 해 위해서 지만 아직 일시 관찰 실 관리 교사 지정 못했 배 교사 보건 교사 관리 맡 으면 학생 돌볼 의심증 상 학생 확진 판정 으면 보건 실 폐쇄 상황 올 다며 학교 에서 업무 분담 돼야 지침 상 누가 역할 해야 는지 명확 보건 교사 아예 학교 지난 기준 전국 만 초중 고등학교 특수 학교 배치 된 보건 교사 만 학교 보건 교사 보건 교사 간호사 더한 보건 인력 학교 전체 인 곳 이윤경 참교 육 학부모회 서울 지부장 아이 마스크 쓰 교시 버틸 을지 겠 다며 몸 학생 같이 사 가족 환자 임산부 학생 등교 수업 선택 권 어야 한다고 박채영',
#  '경찰 로고 신채 린 경찰 로고 신채 린 서울 이상학 경찰 지적 장애 갖 또래 학생 때려 중상 입힌 혐의 중학생 검찰 송치 서울 강동 경찰서 최근 중학생 군 공동 폭행 혐의 구속 해 검찰 송치 했으며 혐의 군 불 구속 송치 밝혔 지난달 서울 강동구 골목 주차장 에서 피해 학생 폭행 혐의 지적 장애 앓 던 알려진 피해 학생 머리 다쳐 병원 옮겨져 수술 전해졌 당시 현장 학생 었 지만 경찰 군 군 만 폭행 관여 경찰 조사 에서 피해 학생 모욕 해 화 서 때렸 진술 알려졌 코리아',
#  '안병용 의정부 시장 이천화 희생자 합동 분향소 헌화 사진 제공 정 부시 안병용 의정부 시장 이천화 희생자 합동 분향소 헌화 사진 제공 정 부시 안병용 의정부 시장 승조 충남 지사 이천화 희생자 조문 간담 사진 제공 정 부시 안병용 의정부 시장 승조 충남 지사 이천화 희생자 조문 간담 사진 제공 정 부시 안병용 의정부 시장 이천화 희생자 조문 뒤 엄태준 천 시장 위 사진 제공 정 부시 안병용 의정부 시장 이천화 희생자 조문 뒤 엄태준 천 시장 위 사진 제공 정 부시 안병용 의정부 시장 천 시 서희 청소년 문화 센터 강당 마련 된 이천 물류 창고 화재 희생자 합동 분향소 찾 조문 월일 천 시 소재 물류 창고 에서 발생 화재 사상자 발생 했으며 화재 원인 현재 조사 안병용 시장 합동 분향소 헌화 마친 뒤 유족 깊 조의 표 엄태준 천 시장 보다 빠른 사고 수습 의정부 시 경기도 시장 군수 협의회 차원 에서 협조 겠 위로 한편 안병용 시장 천 시청 방문 해 협의회 의정부 시 성금 각 만원 총 만 전달 바 권 자',
#  '이재용 삼성전자 부회장 대 국민 사과 상대 수사 재판 영향 끼칠지 주목 된다 검찰 제일모직 삼성물산 합병 경영 권 승계 의혹 관련 해 부회장 수사 선상 올려 법원 에서 부회장 뇌물 사건 파 기환 송심 진행 서울 중앙 지검 경제 범죄형 사 부 최근 정현호 삼성전자 사장 최치훈 삼성물산 이사회 의장 김태한 삼성 바이오 로직스 대표 삼성 사장 급 임원 잇따라 소환 조사 제일모직 삼성물산 합병 통한 경영 권 승계 의혹 연결 된 삼성 바이오 분식 회계 의혹 확인 위해서 검찰 조만간 임원 신병 처리 방향 결정 부회장 소환 조사 관측 된다 부회장 대국민 사과 불구 검찰 계획 대로 수사 진행할 보인다 검찰 관계자 부회장 발표 대한 별도 입장 다며 수사 의지 충분히 지난해 수사 관여 던 검찰 관계자 사과 사과 수사 수사 전성인 홍익 대 경제 학부 교수 수사 지휘 이복 현 경제 범죄 형사 부장 과거 부터 수사 어 온 만큼 자발 수사 일정 회피 본다고 부회장 이날 경영 권 승계 의혹 논란 된 사과 지만 경영 권 승계 명확히 인정 았 향후 검찰 조사 대비 위한 차원 풀이 된다 판사 출신 변호사 부회장 경영 권 승계 과정 었 다는 인정 다면 경영 권 승계 이전 상태 복구 해야 한다는 요구 직면 밖에 었 부회장 사과 국정 농단 사건 재판 유리 게 작용 할지 지켜봐야 한다 대법원 지난해 부회장 박근혜 대통령 경영 권 승계 작업 관련 부정 청탁 인정 양형 법원 부회장 사과 권고 삼성 준법 감시 위원회 운영 감경 사유 될 반면 시민 에서 준 법 감 시위 도입 면죄부 비판 서울 고법 형사부 재판장 정준영 지난해 미국 연방 양형 지침서 장 모티브 준법 감시 제도 도입 처음 거론 자 정치 권 시민 단체 재벌 총수 봐 라며 제기 특검 정 재판장 불 공정 재판 진행 다면서 대한 기피 신청 까지 냈 특검 한국 특유 재벌 체제 에서 준법 감시 제도 실효 성 준 법 감시 제도 도입 양형 반영 법 근거 현직 판사 법원 내부 통신망 공개 준법 감시 제도 양형 반영 비판 글 올리 그럼에도 준 법 감시 제도 도입 부회장 감형 반영 가능 성 여전히 남 서울 고법 형사부 재판장 배준 현가 지난달 특검 정 재판장 기피 신청 기각 면서 법원 준법 감시 제도 도입 유리 양형 사유 고려 해도 위법 판단 재판부 현행 양형 기준 양형 요소 규정 돼 진지 반성 준법 감시 제도 도입 해당 될 특검 기피 신청 기각 대해 대 법원 재항고 윤지원 이혜리',
#  '동영상 앵커 다음 고등학교 학년 부터 순차 인 등교 수업 시작 교실 방역 난제 등장 습니다 바로 이른 더위 인데요 교실 에어컨 틀 자니 코로나 전파 가능 성 입니다 김종균 입니다 등교 수업 준비 선생 님 벌써 여름 교실 걱정 입니다 이종대 서울 도선 교사 선생 님 께서 걱정 부분 마스크 쓰 씩 수업 대한 체력 인 부담 다음 더위 걱정 계십니다 학교 에서 마스크 착용 의무 입니다 아무리 더워도 학생 교실 에서 마스크 쓰 공부 해야 합니다 시원 에어컨 입니다 지난 교육부 내놓 등교 개학 시 지켜야 수칙 면 에어컨 이나 공기 청정기 사용 권고 습니다 교실 에어컨 통해 바이러스 전파 될 가능 성 우려 해섭니다 하지만 최근 기온 오르 면서 교실 에어컨 사용 수칙 그대로 적용 어려워 보입니다 설대우 중앙 대 약학 대학 교수 마스크 굉장히 중요 보호 수단 인데 기온 높 에어컨 틀 마스크 벗 음 해서 오히려 학생 위험 빠질 거든요 마스크 벗 에어컨 켜 상황 자주 교실 환기 방법 외 뾰족 어 보입니다 정은경 중앙 방역 대책 본부 장 현재 에어컨 사용 더라도 수시로 창문 통해서 환기 같이 면서 사용 면 가능 어서 부분 대해서 계속 전문가 의견 모아서 교실 창문 열 어 에어컨 틀 자는 의견 나왔 습니다 이재갑 한림 대 강남성심병원 감염 교수 어느 전력 낭비 고려 더라도 환기 시켜 창문 에어컨 방향 반대쪽 해서 공기 흐름 쪽 방향 흐를 게끔 창문 열 어 에어컨 트 방법 고려 필요 요 여름 방학 줄여 교실 수업 해야 선생 님 학생 혼란 스럽 습니다 교육부 에어컨 사용 대한 새로운 지침 마련 지만 아직 결정 된 건 습니다 김종균 입니다 당신 제보 됩니다 여러분 소중 제보 기다립니다 검색 해 채널 추가 전화 메일 온라인 제보 권 자',
#  '사망자 발생 경기 천 물류 창고 화재 현장 에서 경찰 소방 관계 기관 세 째 합동 감식 고용 노동부 시공사 대한 특별 감독 착수 이날 현장 감식 불 시작 된 지점 특정 건물 지하부 탄 흔적 분석 초점 맞춰졌 건물 전체 설치 된 전기 가스 시설 대한 감식 병행 경찰 사고 초기 마찬가지 불 건물 지하부 에서 시작 된 추정 경찰 관계자 차 현장 감식 대한 국립 과학 수사 연구원 최종 감정 결과 언제 나올 예단 어렵 이날 노동부 이천 물류 창고 공사 현장 시공사 상대 부터 주간 특별 감독 들어간다고 밝혔 특별 감독 화재 사고 현장 뿐 라 원청 시공사 인 건설 업체 본사 건우 시공 인 전국 물류 냉동 창고 곳 대상 한다 아울러 이번 사고 희생자 대부분 하청 업체 소속 일용직 노동자 인 만큼 건우 하청 노동자 위한 안전 조치 의무 제대로 이행 는지 점검 계획 노동부 이번 대형 화 재발 막 전국 건설 현장 곳 대상 부터 주간 긴급 감독 벌일 예정 최인진 이효상',
#  '동영상 앵커 코로나 신규 확진 자 발생 해 만 최저치 기록 습니다 방역 당국 생활 거리 두기 새로운 일상 될 도록 개인 방역 수칙 지켜줄 강조 습니다 한영규 보도 합니다 코로나 신규 확진 자 하루 동안 발생 습니다 지난 이후 만 최저치 기록 습니다 신규 환자 검역 단계 에서 확진 됐 국내 에서 지역 감염 사례 었 습니다 수도 권 대구 경북 전국 모든 지역 에서 사흘 연속 신규 환자 발생 었 습니다 김강립 중앙 재난 안전 대책 본부 총괄 조정관 최근 안정 인 방역 상황 불구 코로나 위험 끝나 았 다는 명심 해 십시오 손 씻 기침 예절 마스크 착용 방역 수칙 철저히 지켜 실 당부 드립니다 방역 당국 상황 악화 언제 든 강화 된 거리 돌아갈 밝히 습니다 생활 거리 두기 새로운 일상 될 도록 개인 함께 노력 필요 강조 습니다 정은경 중앙 방역 대책 본부 장 아프 면 머물 팔 간격 건강 거리 두기 손 씻 기침 예절 매일 이상 환기 주기 인 소독 거리 멀 어 져도 마음 가까이 라는 개인 방역 대 기본 수칙 준 해 실 당부 드립니다 세 이상 노인 고위험 군 가급적 머물 아플 보건소 연락 선별 진료소 방문 해 진료 아야 합니다 외출 거리 두기 어려운 밀폐 된 장소 중요 합니다 특히 연휴 기간 여행 모임 졌 가족 이나 여행 동행자 이상 유증 상자 발생 면 선별 진료소 에서 검사 필요 합니다 영규 입니다 당신 제보 됩니다 여러분 소중 제보 기다립니다 검색 해 채널 추가 전화 메일 온라인 제보 권 자',
#  '서울 이상학 밤 귀가 던 여성 성범죄 시도 대 남성 구속 됐 서울 강남 경찰서 강 간상 해 혐의 구속 해 수사 밝혔 지난달 피해 여성 인근 지하철 역 에서부터 따라가 성폭행 시도 려다가 도망간 혐의 는다 피해 여성 저항 자 놀란 도망갔으며 신고 주변 수색 던 경찰 체포 됐 피해 여성 과정 에서 경미 부상 입 전해졌 코리아',
#  '메건 마클 왕 자비 아들 아치 모습 세이브 칠드런 인 스타 그램 캡처 재판매 메건 마클 왕 자비 아들 아치 모습 세이브 칠드런 인 스타 그램 캡처 재판매 코로나 기부 유도 세이브 칠드런 인 스타 그램 올려 런던 연합뉴스 박대 특파원 영국 해리 왕자서 식스 공작 메건 마클 왕자 비서 식스 공작부인 부부 아들 첫 돌 맞 새 영상 공개 현지 스카이 면 해리 왕자 부부 이날 국제 구호 개발 비 정부 기구 인 세이브 칠드런 인 스타 그램 계정 동영상 올렸 영상 마클 왕 자비 아들 아치 무릎 앉힌 뒤 그림책 오리 토끼 읽 어 모습 담 았 다아 치 엄마 무릎 위 에서 이리저리 움직이 는가 면 책 었 다가 떨어뜨리 영상 해리 왕자 찍 었 이날 아치 돌 맞 날 부부 첫째 아이 인 아치 지난해 런던 포틀랜드 병원 에서 태어났 정식 이름 아치 해리슨 마운트배튼 윈저 해리 왕자 부부 신종 코로나 바이러스 감염증 코로나 대응 기금 마련 돕 이날 세이브 칠드런 소셜 미디어 영상 올렸 해리 왕자 부부 대변인 공작 공작부인 수백만 어린이 음식 배움 필요 자원 시급 다는 알리 었 다면서 공작부인 아치 가장 책 읽 어 설명 왕위 고위 구성원 에서 독립 선언 해리 왕자 부부 영국 떠난 뒤 캐나다 거쳐 현재 미국 로스앤젤레스 정착',
#  '국내 최초 건립 노동 문학관 첫 삽 떴 노동 문학관 건립 위원회 위원장 정세훈 시인 이날 오전 충남 홍성군 광천읍 월림리 현장 에서 착공식 갖 관 목표 본격 인 건축 공사 착수 민족 시각 문화 교류 협회 배 인석 상임 이사 진행 된 착공식 강원 민예총 김흥우 이사장 정의당 이선영 충남 의원 더불 어 민주당 최선경 군 의원 이부균 홍성군 행정 복지 국장 신 주철 광천 읍장 가수 이지훈 참석 착공 축하 착공식 에서 정세훈 위원장 일제 강점 시기 카프 전태 열 사 분 신 이후 노동 문학 관련 소중 자료 손실 다며 자료 모아서 보관 해야 겠 나아가 노동 문학 조명 노동 문학 향후 유구 토록 한국 올바른 길잡이 도록 노동 문학관 건립 고자 한다고 강조 정 위원장 건축 현재 아파트 줄여 건립 자금 마련 지만 건축비 예상 보다 많이 들어가 부족 채우 활용 모금 다방면 노력 다면서 향후 충청남도 또는 홍성군 협의 해 현 부지 노동 문학관 확장 중심 주변 관련 시비 동산 조각 공원 예술 마을 조성 해 전국 에서 보다 관람객 찾아오 예술 명소 조성 밝혔 이곳 에서 매년 문학 그림 풍물 춤 사진 노래 노동 관련 모든 예술 장르 참여 전국 노동 예술제 박일 개최 될 예정 예술제 향후 세계 노동 예술제 확대 승화 시켜 노동 문학관 국내 물론 세계 널리 알리 물론 노동 문학 세계 명소 추진 된다 착공식 김윤환 시인 목사 감사 예배 인도 시작 됐 김 목사 시인 등단 노동 문학가 김 목사 노동자 땀 눈물 희망 담 노동 문학관 첫 삽 뜨 고귀 라며 자본 도구 화 어 버린 인간 노동 어디 향해야 할지 방향 정립 도록 노동 문학 그동안 걸어온 발자취 기록 기억 공간 길 기원 한다고 건축 설계 담당 건축사 사무소 노둣돌 이윤하 대표 시인 노동 문학관 건립 소식 접하 먼저 자청 해 설계 담당 겠 자원 해 함께 게 됐 다며 건물 디자인 수평선 노동 일상 성 평등 권 가치 상징 한다 수직선 노동 인권 진보 대한 기대 담 단순 화 장래 외부 확장 염두 었 전체 너무 멋 스럽 으면서 풍부 내용 담 책 품 공간 구상 해 설계 설명 정세훈 위원장 리얼리스트 상임 위원 대표 한국작가회의 이사 한국 민예총 이사장 대행 소년 희망 센터 건립 추진 위원회 위원 역임 했으며 제회 기독교 문화 대상 수상 현재 인천 민예총 이사장 황 해 평화 포럼 평화 인문 분과 위원 위기 청소년 친구 어게인 이사 소년 희망 센터 운영 위원 활동 정창교 국민 일보',
#  '기사 섹션 분류 안내 기사 섹션 정보 해당 언론사 분류 습니다 언론사 개별 기사 이상 섹션 중복 분류 습니다 닫',
#  '이남식 서울 예대 총장 왼쪽 안심 키트 사진 제공 서울 예대 이남식 서울 예대 총장 왼쪽 안심 키트 사진 제공 서울 예대 서울 예대 안심 대문 사진 제공 서울 예대 서울 예대 안심 대문 사진 제공 서울 예대 산 강근주 월일 부터 대 면 수업 들어가 서울 예술 대학교 교내 안심 대문 안심 대기실 설치 재학 생 교직원 전원 전달 안심 키트 제작 학생 안심 등교 환경 조성 나섰 코로나 사태 초기 던 월일 입학 학생 처 감염병 관리 대응 팀 구성 서울 예대 그동안 수차례 학교 시설 방역 비대 면 수업 진행 인 학생 위한 대응 조치 안내문 발송 코로나 확산 방지 위한 조치 취해 왔 월일 대 면 수업 개시 확정 된 뒤 학생 등교 위한 준비 본격 서 우선 교내 안심 대문 안심 대기실 설치 운영 등교 학생 유증 상자 무증 상자 확진 자 선별 적절 초기 대응 조치 취하 고자 설치 된 안심 대문 서울 예대 상징물 인 빨간 다리 예술 정보 센터 아래 자리 교내 출입 모든 학생 안심 대문 에서 선 별지 작성 제출 후 열 감지 카메라 통과 해야 학교 들어설 안심 대문 통과 시 유증 상자 혹은 고열 의심 증상 자 발견 면 안심 대문 인근 안심 대기실 안내 후 관내 보건소 선별 진료소 연락 해 추후 조치 취하 게 된다 안심 대문 현재 교직원 대상 시범 운영 며 월일 부터 본격 운영 된다 서울 예대 학생 안심 대문 이용 안내 관련 홍보 동영상 제작 해 홈페이지 게시 학교 구성원 안심 키트 학생용 교직원 용 총 여개 손소 독제 살균 소독 제 마스크 살균 티슈 비타민 음료 구성 돼 안심 키트 안심 대문 통과 재학 생 교직원 전원 전달 된다 안심 키트 동봉 된 개인 용 살균 소독 제 월일 박인태 에이치 엔 티 대표 서울 예대 광고 창작 전공 재학 생 기부 서울 예대 대 면 수업 교내 코로나 감염증 확산 대비 지침 사항 홈페이지 통해 안내 지침 코로나 관련 정보 예방 생활 수칙 행동 요령 대면 수업 이후 학교 생활 대응 감염 의심 자 확진 자 발생 시설 관리 대응 교내 방역 소독 지침 구성 돼 한편 서울 예대 코로나 사태 장기 화 어려움 겪 재학 생 응원 서울 예대 재학 생 교수 연예인 동문 메시지 담 코로나 극복 위한 릴레이 응원 영상 게재 오디션 프로그램 미스터 트롯 출연 옥 진욱 공연 학부 재학 시작 실용음악 전공 우디 박 교수 배우 장현성 연극 전공 안재욱 연극 전공 장항준 감독 연극 전공 개그맨 김용만 방송 영상 전공 김진수 연극 전공 참여 한편 코로나 극복 응원 영상 서울 예대 공식 유튜브 페이스북 인 스타 그램 에서 볼 권 자',
#  '지적 장애 중학생 학교 동갑내기 으로부터 집단 폭행 당해 중태 빠졌 가해자 학교 운동 선수 인 알려졌 다일 서울 강동 경찰서 지난달 지적 장애 학교 동갑내기 때려 중태 빠지 게 혐의 중학교 학년 군 공동 상해 혐의 구속 불 구속 상태 검찰 송치 밝혔 군 지난달 새벽 시 쯤 서울 강동구 지상 주차장 에서 피해자 머리 몸 발 차 뇌출혈 인한 중태 빠지 게 혐의 군 지난달 새벽 시 쯤 서울 강동구 지상 주차장 에서 피해자 머리 몸 발 차 뇌출혈 인한 중태 빠지 게 혐의 경찰 조사 에서 피해자 군 아버지 흉내내 가해자 친구 성적 모욕 전해들 어 화 서 때렸 진술 알려졌 피해자 가족 피해 학생 지적 장애 급 판정 또래 보다 인지 능력 낮 누군가 의도 모욕 며 오히려 군 지속 인 폭행 시달렸 주장 이진한 매일 경제',
#  '남양유업 홍보 대행사 통해 경쟁사 비방 정황 드러나 경찰 수사 착수 확인 됐 다일 서울 종로 경찰서 홍원식 남양유업 회장 명예 훼손 혐의 입건 해 수사 밝혔 경찰 면 남양유업 지난해 초 홍보 대행사 동원 해 온라인 카페 경쟁사 비방 내용 댓글 게시 혐의 경찰 남양유업 부산 소재 홍보 대행사 통해 경쟁사 비방 조직 관여 정황 파악 수사 진행 전해졌 이번 수사 비방 대상 된 업체 경찰 남양유업 고소 해 시작 된 알려졌 경찰 관계자 수사 진행 맞 지만 구체 혐의 밝히 어렵 설명 남양유업 관계자 경찰 조사 인 사안 라 추가 설명 밝혔 이윤식 매일 경제',
#  '동영상 앵커 전국 에서 코로나 방역 대책 생활 방역 전환 됐 는데요 피해 컸 던 대구시 지역 상황 맞 강력 방역 대책 추진 겠 다며 교육부 방침 달리 각급 학교 등교 시점 조정 발표 해 큰 혼선 초래 습니다 마스크 착용 의무 화 강조 면서 위반 면 처벌 겠 해 시민 반발 샀 습니다 정지훈 입니다 생활 방역 전환 전국 상황 달리 코로나 대유행 겪 대구시 지역 상황 맞 강력 방역 대책 추진 발표 습니다 성급 복귀 보다 철저 방역 무게 둘 밖에 다며 등교 수업 시기 조정 언급 습니다 고등학교 학년 부터 시작 해 순차 실시 한다는 교육부 방침 불구 대 구 상황 맞 게 조정 방안 대구시 교육청 긴밀히 협의 해 나갈 입니다 하지만 대구시 교육청 시 방역 대책 우려 대해 공감 한다면서 구체 실무 협의 없이 이뤄진 대구시 일방 인 발표 당혹 스런 표정 입니다 같이 공감 습니다 아이 전하 게 등교 게 가장 중요 다만 세부 방식 이나 초중 고별 학교 계속 소통 습니다 온라인 수업 등교 수업 병행 만 업무 부담 큰 일선 교사 대구 시장 한마디 발언 혼선 초래 면서 종일 등교 일정 묻 학부모 전화 시달려야 습니다 선생 님 원격 수업 병행 해야 아이 아야 면 교사 업무 너무 과중 됩니다 학부모 까지 기다렸 아이 데리 어야 불편 함 다는 거 죠 대중교통 공공시설 의용 마스크 착용 의무 화 위반 면 처벌 겠 다는 대구 시장 행정명령 발언 논란 입니다 시민 마스크 쓰 당연 라면서 여태껏 자발 거리 두기 참여 해 왔 뒤늦 강제 처벌 까지 겠 다는 건 민심 제대로 읽 탁상행정 라 꼬집 었 습니다 연합뉴스 정지훈 입니다 연합뉴스 기사문 제보 카톡 라인',
#  '연합뉴스 연합뉴스 서울시 재난 긴급 생활비 서울 시민 지급 선불카드 일부 대형 마트 온라인 쇼핑몰 에서 결제 가능 알려 면서 사용 처 대한 혼란 당초 시 지역 소상 공인 돕 대형 마트 온라인 에서 사용 제한 된다고 다일 서울시 면 정부 지원금 별도 시 중위 소득 이하 가구 최대 만 까지 지원 재난 긴급 생활비 지역 사랑 상품권 아닌 선불카드 으면 쿠팡 번가 마켓 온라인 쇼핑몰 대형 마트 인 홈플러스 에서 사용 가능 온라인 쇼핑몰 입점 업체 소상 공인 면서 회사 주소 서울 인 업체 해 결제 가능 다는 게 서울시 측 설명 예 어 쿠팡 다수 판매자 소비자 간 거래 사이트 에서 중개 오픈 마켓 영업 방식 갖추 이때 판매자 서울 소재 소상 공인 면 결제 된다는 다대 형 마트 사 에서 이마트 롯데마트 에서 사용 지만 홈플러스 에서 가능 나타났 시 관계자 이마트 롯데마트 에서 결제 시스템 상 기프트카드 형태 선불카드 업체 기프트카드 인식 해 결제 막혀 자체 발행 상품권 홈플러스 에서 자사 기프트카드 인식 해 결제 된다 라며 결제 시 기프트 카드 인식 느냐 냐 기술 설명 일각 에서 현재 제각각 인 지원금 사용 처 대한 세세 가이드라인 필요 다는 지적 나온다 부터 저소득층 제외 일반 국민 정부 지원금 신청 시작 면 사용 처 대한 혼란 더욱 커질 이때 지원금 역시 선불카드 선택 해 최대 만 까지 게 반복 될 시 관계자 홈플러스 사용 처 에서 뺄 건지 이마트 롯데마트 추가 건지 전국 사용 처 맞춰야 부분 덧붙였 권영 네이버 에서 한국일보 세요 뉴 잼 면 재밌 레터 구독 한국일보 닷컴 바로',
#  '경기도 교육감 승인 초등 학교 보건 교과서 디지털 성범죄 관련 성 교육 내용 추가 해 싣 방안 추진 된다 사 단 법인 보건 교육 포럼 초등 학교 학년 용 보건 교과서 인 생활 보건 대해 사이버 성폭력 불법 촬영 그루 밍 범죄 반영 해 수정 경기도 교육청 승인 신청 계획 알려졌 경기도 교육청 관계자 아직 수정 승인 요청 들어오 았 지만 신청 들어오 면 심사 들어갈 예정 다년 부터 일부 학교 에서 쓰이 해당 교과서 국정 검정 교과서 달리 교육감 승인 인 서이 교육감 인 서 정규 교과 과정 외 쓰이 며 학교장 선택 해 활용 수정 된 생활 보건 사이버 성폭력 관련 내용 새로 추가 된 알려졌 초등 학년 정본 사이버 공간 에서 성 인 괴롭힘 불법 촬영 물 유포 협박 불법 촬영 통한 불법 촬영 물 공유 디지털 성폭력 될 다는 내용 추가 됐 한다 불법 촬영 대해서 촬영 자체 만 범죄 될 불법 촬영 물 저장 거나 공유 뿐 라 클릭 조차 라는 경고 담겼 학생 가해 행위 무엇 인지 명확 게 인식 겠 다는 취지 다수 정본 미성년자 성 착취 사건 인 번방 에서 된 그루 밍 대해서 다뤄 그루 밍 온라인 대화 이용 해 친절 베풀 며 호감 신뢰 쌓 뒤 성 인 대화 거나 신체 사진 영상 요구 해 성폭력 위한 협박 도구 활용 행동 전체 한다고 설명 알려졌 초등 학년 정본 경계 란 안전 위한 최소한 장치 므로 경계 함부로 넘 아야 한다 중략 여러 활동 통해 경계 들어갈 반드시 동의 구해야 한다는 내용 추가 됐 한다이 같이 추가 된 내용 기존 성 교육 피해 예방 만 초점 맞추 범죄 명확히 알리 교육 소극 었 다는 비판 반영 보인다 유소연 조선일보',
#  '박사 방 운영 자 조 주빈 공범 부 따 강훈이 구속 기소 됐 강 에겐 조 함께 윤장현 광주 시장 사기 쳐 돈 혐의 포함 됐 서울 중앙 지검 디지털 성범죄 특별 수사 태 스 포스 이날 강 아동 청소년 성 보호법 상 음란물 제작 강제 추행 형법 상 강제 추행 강요 협박 사기 혐의 재판 넘겼 강 조 함께 지난해 아동 청소년 명과 성인 협박 해 성 착취 영상 제작 텔레 그램 통해 돈 혐의 다강 조 짜 윤 시장 사기 쳐 만 강 지난해 공직 선거법 위반 항소심 재판 앞두 던 윤 시장 유리 재판 게 해 겠 거짓말 해 만 씩 차례 돈 았 조 판사 행세 강 판사 비서관 행세 해 윤 시장 속였 윤 시장 지난해 항소심 에서 심 똑같이 징역 집행유예 선고 았 지난 대 법원 에서 형 확정 됐 강 혼자 벌인 범행 었 강 지난해 지인 인 여성 얼굴 사진 나체 사진 합성 딥 페이크 사진 여러 장 사회관 계망 서비스 게시 검찰 경찰 송치 성 착취 물 제작 혐의 일부 불기소 처분 강 딥 페이크 사건 경찰 검거 된 지난해 월일 이후 윤 시장 사기 쳤 뿐 박사 방 관여 았 판단 검찰 조 공범 모두 최고 무기 징역 처벌 범죄 단체 조직 죄 보강 수사 거쳐 추가 기소 방침 검찰 범죄 단체 조직 혐의 발부 압수수색 영장 지난달 강 주거지 에서 자료 확보 해 분석 조 강 앞서 구속 기소 된 수원 영통구 청 복무 요원 강모 태평양 모군 박사 방 운영 깊이 관여 범죄 단체 조직 혐의 회사원 장모 김 모씨 조 가상 통화 입금 거나 일정 역할 맡 범죄 단체 가입 활동 혐의 입건 검찰 관계자 조 가상 통화 입금 단순 유료 회원 라 성 착취 물 제작 유포 필요 자금 지급 성 착취 범행 자금 제공 자 공소장 었 다며 강 사건 조 사건 병합 해 심리 해 달 법원 요청 계획 서울 중앙 지법 김태균 영장 전담 부장 판사 이날 조 지시 손석희 대표 이사 윤 시장 만나 돈 조 전달 공범 김 모씨 이모 대한 구속 영장 발부 허 진무',
#  '한국 미국 개국 다크 웹 공조 수사 결과 발표 이후 폐쇄 문구 노출 된 사이트 화면 사진 경찰청 제공 텔레 그램 박사 방 에서 운영 자 조 주빈 도와 대화방 운영 관리 관여 공범 부 따 강훈 이른바 다크 웹 통해 아동 청소년 성 착취 물 대거 유포 혐의 웰컴 투 비디오 운영 자 손정우 측 범죄인 인도 절차 거쳐 미국 송환 가혹 다는 취지 탄원서 법원 제출 해 논란 법조 계 면 손씨 부친 손모 범죄인 인도 심사 맡 서울 고법 형사부 최근 탄원서 제출 손씨 미국 송환 될 국내 법원 유죄 판결 중복 국제 자금 세탁 혐의 만 이하 징역형 고려 해 선처 호소 반성 다는 비판 온라인 에서 들끓 었 아버지 손씨 용지 장 분량 탄원서 통해 살아온 날 보다 살아갈 날 아들 식생활 언어 문화 미국 송환 면 너무나 가혹 전해졌 특히 아들 불우 가정 환경 언급 며 용돈 벌 어 고자 시작 었 나중 큰 이사 려고 돈 모으 려 밝혔 이어 원래 천성 악하 강도 살인 강간 미수 범죄 저지른 아들 감쌌 지난달 범죄인 인도 업무 담당 법무부 국제 형 사과 탄원서 제출 알려졌 다손 인도 심사 심문 앞두 법조 계 에서 과거 사례 비춰 손씨 미국 송환 가능 성 큰 인도 심사 에선 범죄인 유무죄 가리 라 인도 정당 성 여부 만 따지 손씨 대한 강제 송환 절차 지난해 미국 법무부 한국 경찰청 국제 공조 수사 발표 기점 이뤄졌 법무부 국내 법원 에서 판결 혐의 뺀 국제 자금 세탁 부분 만 미국 법원 넘긴다는 방침 라 이중 처벌 논란 에서 자유 롭 최근 간년 서울 고법 인도 심사 청구 결정 내린 사건 분석 면 접수 된 건 거절 결정 단 건 불과 검찰 출신 변호사 법원 입장 에서 미국 송환 거절 명분 다며 탄원서 아들 피해자 인 처럼 묘사 법원 피고인 반성 더욱 엄격히 검토 추세 볼 현명 못한 행동 분석 서울 중앙 지검 디지털 성범죄 특별 수사 태 스 포스 미성년자 상대 성 착취 물 제작 디지털 공간 에서 유포 박사 방 사건 주요 피의자 인 부 따 강훈 구속 기소 청소년 성 보호법 상 음란물 제작 법 강제 추행 혐의 기소 됐 주범 조주 빈씨 박사 방 운영 혐의 지난해 부터 사이 공직 선거법 위반 혐의 재판 윤장현 광주 시장 접근 해 사기 친 혐의 조 심 재판장 강 판사 비서관 인 처럼 위장 해 유리 재판 게 해 겠 거짓말 해 만 가로챈 혐의 검찰 조 마찬가지 강군 최초 기소 에서 범죄 단체 조직 죄 혐의 적용 았 검찰 특히 강군 수사 상황 설명 면서 가상 화폐 입금 유료 회원 아닌 성 착취 범행 자금 제공 자 표현 해 눈길 끌 었 조 범죄 도와 준 대 공범 이날 구속 됐 서울 중앙 지법 김태균 영장 전담 부장 판사 이날 사기 범죄 수익 닉 규 제법 위반 혐의 경찰 신청 김 모씨 이모 명의 구속 영장 발부 김 부장 판사 범죄 혐의 내용 피의자 역할 가담 피해 규모 비춰 높 처단형 예상 된다며 수사 진행 경과 수사 심문 과정 에서 진술 태도 볼 증거 인멸 도망 염려 구속 사유 밝혔 조 요구 따라 손석희 사장 윤 시장 직접 만나 돈 았 조 전달 혐의 안병수 이도형 세상 눈',
#  '오후 대전 유성구 인터 시티 호텔 에서 열린 산업 지원 다목 방사광 가속기 구축 부지 선정 평가 위원회 에서 심사 위원 부지 선정 평가 정부 추진 조억 원대 초대 형 연구 시설 조성 사업 대상 후보 부지 전남 나주 혁신 도시 선정 면서 치열 게 펼쳐진 세대 원형 방사광 가속기 유치 첫 관문 통과 게 됐 동안 지역 간 총력전 양상 전개 된 방사광 가속기 유치 전남 나주 강원춘 천충 북 오창경 북 포항 치열 파전 펼쳐왔 다일 전남 면 과학 기술 정보 통신부 이날 대전시 인터 시티 호텔 층 파인 홀 에서 산업 지원 다목 방사광 가속기 구축 부지 선정 평가 위원회 열 전남 나주 혁신 도시 충북 청주 오창 테크노폴리스 산단 대상 후보지 각각 선정 발표 최종 우선 협상 대상지 선정 평가 위 해당 부지 순차 방문 해 진행 예정 인 현장 실사 평가 점수 달려 구체 인 현장 방문 일정 프레젠테이션 발표 평가 후 별도 공지 된 가운데 해당 지역 도착 교통 상황 고려 해 당일 별도 지자체 통지 예정 평가 위원 공정 성 확보 자체 마련 교통수단 통해 단체 이동 한다 평가 위 후보지 현장 확인 대상 지역 별 분간 비 공개 방식 진행 며 현장 확인 전후 지자체 관계자 개별 접촉 원천 차단 된다 후보지 실사 현장 질 응답 가능 지자체 해당 업무 담당 국장 급 관리자 포함 해 이내 관계자 참석 가운데 간단 설명 자료 만 제공 될 예정 방사광 가속기 평가 지표 기본 요건 입지 조건 지자체 지원 전남 만점 기준 에서 최고 점수 달린 입지 조건 평가 지표 미래 자원 확장 가능 성 국가 균형발전 기여 가능 성 부지 안정 성 비롯 해 차별 화 된 지자체 지원 집중 부각 보인다 무안 승하 세상 눈',
#  '아내 폭행 해 살해 혐의 구속 기소 된 유승현 김포시 의회 의장 연합뉴스 아내 골프채 폭행 해 숨지 게 혐의 구속 기소 된 유승현 경기 김포시 의회 의장 대해 검찰 심 이어 심 에서 징역 구형 검찰 서울 고법 형사 부부 장판 사 정준영 송영승 강상욱 심리 열린 유 의장 살인 혐의 사건 항소심 결심 공판 에서 원심 구형 대로 징역 선고 해 달 밝혔 검찰 피고인 살해 범행 의도 계속 부인 지만 살해 동기 명백 다며 피해자 연남 내연 관계 상황 듣 게 자 범행 저지른 지적 면서 피고인 피해자 죽 구타 후 필요 조치 동안 방기 해 현장 에서 사망 게 다며 엄벌 처해 달 강조 반면 유 의장 측 변호인 피고인 아내 사망 이르 게 깊이 반성 다면서 피고인 살인 고의 었 심 양형 부당 변론 유 의장 역시 제 잘못 유명 달리 아내 진심 머리 숙여 사죄 한다면서 재판부 가족 모두 가엽 게 여겨 무너진 온 가정 설 기회 될 도록 따뜻 게 살펴 달 호소 울먹이 며 미리 준비 해 온 글 낭독 유 의장 최후 진술 마치 자리 앉 한동안 고개 숙이 었 유 의장 지난해 오후 김포시 자택 에서 술 취해 아내 골프채 주먹 때려 숨지 게 뒤 자수 구속 기소 된 유 의장 심 에서 징역 자격정지 선고 항소 심 재판 과정 에서 이번 사건 상해 치사 해당 뿐 라며 살인 고의 성 전면 부인 바 유 의장 부터 까지 제대 김포시 의회 의장 지냈 다나 진희 세상 눈',
#  '미성년자 성 착취 물 제작 유포 텔레 그램 박사 방 운영 자 조 빈 구속 기소 사기 행각 도운 혐의 대 공범 구속 됐 조 범행 공분 며 번방 에서 감방 외친 시민 단체 요구 착착 현실 어 모양새 서울 중앙 지법 김태균 영장 전담 부장 판사 사기 범죄 수익 닉 규 제법 위반 혐의 경찰 김 모씨 이모 대해 신청 구속 영장 발부 김 부장 판사 범죄 혐의 내용 피의자 역할 가담 피해 규모 비춰 높 처단형 예상 된다고 영장 발부 사유 밝혔 사실상 혐의 유죄 인정 된다는 뜻 경찰 면 김 조 지시 손석희 대표 이사 사장 윤장현 광주 시장 직접 만난 뒤 로부터 돈 조 전달 혐의 경찰 조사 결과 조 박사 방 운영 텔레 그램 에서 마약 판다고 속이 글 여러 차례 올리 돈 만 가로챈 천만 원대 사기 범행 가담 드러났 경찰 박사 방 운영 조 비롯 해 주요 공범 대한 수사 마무리 한편 조 돈 대화방 이용 회원 추적 주력 경찰 이미 박사 방 유료 회원 전용 대화방 참여 여명 신원 파악 해 입건 했으며 일부 상대 소환 조사 진행 한편 경찰 조 박사 방 함께 운영 지목 닉네임 사마귀 행방 계속 좇 나머지 부 따 강훈 이기 야 이원호 육군 일병 진작 검거 돼 실명 얼굴 신상 정보 공개 구속 기소 됐 거나 군사 재판 회부 앞두 김태훈 사진 연합뉴스 세상 눈',
#  '미래한국 당 지성호 당선인 왼쪽 미래 통합 당 태영 호 당선인 연합뉴스 김정 북한 국무 위원장 신변 상설 제기 미래 통합 당 태영 호 국회의원 당선인 미래한국 당 지성호 당선인 대해 검찰 수사 착수 법조 계 면 서울 중앙지 검 이날 태영 호지 성호 당선인 허위 유포 혐의 고발 당한 사건 형사부 부장 검사 윤진용 배당 앞서 안전 시민 연대 지난 태영 호지 성호 당선인 김종인 통합 당 총괄 선거 대책위 원장현 비상 대책 위원장 서울 중앙 지검 고발 단체 당선인 객관 파악 없이 김 위원장 신변 이상설 확인 듯 발언 함 으로써 허위 유포 국민 안보 불안 자극 주장 태 당선인 당선인 최근 청와대 정부 김 위원장 건강 상설 여러 차례 부인 음 불구 각각 최소한 혼자 걷 못 상태 사망 확신 다가 지난 김 위원장 만 공개 활동 재개 면서 대국민 사과 바 또한 단체 김종인 비대위 원장 총선 하루 앞둔 지난달 회견 에서 선거 끝나 면 확진 자 폭 증 거 전국 에서 의사 편지 쇄도 한다고 언급 부분 삼 검찰 수사 촉구 다나 진희 세상 눈',
#  '서울 여의도 국회의사당 에서 양육비 해 결총 연합회 관계자 양육비 이행 확보 지원 관한 법률 개정안 통과 촉구 연합뉴스 시민 단체 대 국회 에서 양육비 미 이행 부모 제재 강화 법 개정안 통과 시켜야 한다고 촉구 양육비 해 결총 연합회 양해 연 서울 영등포구 국회 에서 양육비 이행 확보 지원 관한 법률 개정안 통과 요구 회견 열 었 양해 연 경제 능력 미성년 아이 부모 부양 으면 생존 다며 양육비 부모 의무 자 아이 생존 권 목소리 높였 양육비 지급 못한 양육자 비율 달 다며 청구 소송 더라도 실제 양육비 비율 불과 꼬집 었 정당 사유 없이 양육비 지급 부모 국가 양육비 대 지급 제 선지급 후 사후 환수 출국 명단 공개 운전 면허 정지 강제 해야 한다고 요구 운전 면허 정지 양육비 제재 사이 인과 관계 논란 지만 해외 에서 양육비 이행 강화 위한 효과 인 조치 꼽힌다 한편 국회 여성 가족 위원회 이날 법안 심사 소위원회 전체 회의 잇따라 열 관련 개정안 의결 개정안 양육비 지급 긴급 지원 이뤄졌 양육비 채무자 대해 국세 체납 징수 본인 동의 신용 정보 보험 정보 요청 운전 면허 정지 처분 가능 도록 골자 한다 더불 어 민주당 정춘숙 의원 미래한국 당 송희경 의원 각각 대표 발 개정안 이날 여가 위 에서 의결 됐 지만 국회 통과 낙관 어려운 상황 소극 인 태도 보인 법제 사법 위원회 거쳐야 이달 회기 끝 대 국회 본회 일정 조차 정해 았 본 회의 열리 으면 법안 자동 폐기 된다 양 해연 관계자 이날 통화 에서 국회 본회의 조속히 열리 길 바란다 며 법안 국회 통과 촉구 행사 계속 진행 예정 밝혔 이종민 세상 눈',
#  '라임 자산 운용 주로 지목 된 김봉현 스타 모빌리티 회장 연합뉴스 경찰 라임 사태 핵심 인물 인 김봉현 스타 모빌리티 회장 은닉 던 억 현금 다발 압수 뒤늦 게 확인 됐 서울 물품 보관소 개인 금고 에서 발견 된 돈 여행 용 가방 만원 권 나뉘 어 어 었 수사 당국 면 경기 남부 경찰청 지능 범죄 수사대 지난 김 회장 대한 수원여객 횡령 사건 수사 마무리 검찰 송치 면서 압류 현금 억만 함께 보냈 앞서 경찰 지난달 도피 던 김 회장 라임 사태 핵심 인물 인 이종필 라임 부사장 서울 성북구 빌라 에서 체포 당시 머물 던 빌라 에서 현금 억만 발견 해 압수 김 회장 라임 사태 별개 경기도 버스 회사 인 수원여객 에서 억 규모 회 삿 돈 횡령 사건 주도 혐의 지난해 구속 영장 청구 된 상태 였 이후 경찰 김 회장 수사 수원여객 횡령 사건 에서 빼돌린 돈 행방 추궁 김 회장 서울 물품 보관소 주소 실토 경찰 지난달 찾아간 물품 보관소 에선 김 회장 가명 보관 던 대형 개인 금고 었 금고 에서 만원 권 가득 찬 여행 용 가방 발견 됐 가방 담긴 돈 액수 억 달했 김 회장 경찰 조사 에서 재향군인회 상 조회 관련 된 돈 밝힌 전해졌 김 회장 라임 사태 수원여객 횡령 혐의 외 재향군인회 상 조회 인수 뒤 억 대 고객 예탁 금 빼돌린 혐의 김 회장 부터 지난해 까지 수원여객 회 삿 돈 억 빼돌린 혐의 혐의 경찰 수사 다가 잠적 해 도피 행각 벌이 던 올해 초 조억 대 피해액 발생 라임 자산 운용 사태 전주 자 정관 계 로비 핵심 인물 꼽히 면서 세간 알려졌 수원 오상 세상 눈',
#  '라임 사태 몸통 지목 된 김봉현 스타 모빌리티 회장 사진 붙잡 수사 경찰 김 회장 은닉 해 온 억 현금 다발 발견 해 압수 확인 됐 경찰 김 회장 검찰 송치 면서 돈 같이 넘겼 수사 당국 면 경기 남부 지방 경찰청 지능 범죄 수사대 지난 김 회장 수원여객 공금 횡령 사건 수사 마무리 수원 지검 송치 면서 까지 압수 현금 억만 같이 넘겼 앞서 경찰 지난달 던 김 회장 라임 사태 핵심 인물 잠적 던 이종필 라임 부사장 서울 성북구 빌라 에서 체포 김 회장 라임 사태 별개 경기도 버스 회사 인 수원여객 에서 억 규모 회 삿 돈 횡령 주도 혐의 지난해 구속 영장 청구 자 잠적 부사장 코스닥 상 장사 리드 경영진 억 대 횡령 혐의 연루 된 드러난 뒤 지난해 부터 행적 감춘 상황 었 경찰 김 회장 검거 당시 머물 던 빌라 에서 현금 억만 발견 해 압수 이후 김 회장 수사 과정 에서 김 회장 수원여객 횡령 사건 통해 빼돌린 돈 행방 추궁 김 회장 입 에서 서울 물품 보관소 주소 끌어내 성공 경찰 지난달 찾아간 물품 보관소 김 회장 사용 가명 보관 던 대형 개인 금고 었 금고 에서 만원 권 가득 찬 여행 용 가방 발견 됐 가방 담긴 돈 액수 모두 억 었 돈 출처 아직 확인 았 다만 김 회장 경찰 조사 에서 재향군인회 상 조회 관련 된 돈 주장 전해졌 김 회장 부터 지난해 까지 수원여객 재무 담당 전무 이사 공모 해 수원여객 회 삿 돈 억 빼돌린 혐의 혐의 경찰 수사 다가 잠적 해 도피 행각 벌이 던 올해 초 조억 대 피해액 발생 라임 자산 운용 사태 전주 자 정관 계 로비 핵심 인물 꼽히 면서 세간 알려졌 최인진',
#  '오거돈 부산 시장 사진 성추행 사건 수사 부산 경찰청 사건 별개 시장 채용 비리 의혹 대해서 수사 착수 부산 경찰청 시민 단체 시장 채용 비리 의혹 제기 며 검찰 제출 고발장 검찰 로부터 이첩 돼 수사 밝혔 서민 민생 대책 위원회 지난달 업무상 위력 의한 추행 직권 남용 혐의 시장 서울 중앙 지검 서울 남부 지검 고발 시장 신원철 서울시 의회 의장 공모 해 형식 인 채용 공고 낸 뒤 특정 직원 불법 채용 주장 한다 집무실 성추행 사건 관련 해 경찰 피해자 진술 확보 못해 시장 대한 피의자 조사 일정 잡 경찰 관계자 부산 성 폭력 상담소 통해 피해자 의사 알아보 으나 현재 까지 피해자 측 조사 수락 여부 밝히 전했 현행법 상 성폭력 사건 피해자 수사 기관 강제 불러 진술 지난달 사퇴 회견 이후 종적 감춘 시장 경남 거제 머물 확인 됐 부산 정치 권 시장 지인 시장 사퇴 이후 거제 펜션 에서 지내 전했 시장 아직 시장 관사 짐 빼 았 한편 미래 통합 당 더불 어 민주당 성범죄 진상 조사단 이날 시장 사건 검찰 고발 조사단 대검찰청 시장 부산 시청 부산 성 폭력 상담소 청와대 관계자 대해 공직 선거법 위반 강제 추행 성폭력 처벌 특례법 위반 직권 남용 혐의 고발 거나 수사 의뢰 조사단 부산 성 폭력 상담소 홈페이지 나온 김외숙 자문 위원 법무법인 부산 출신 현 청와대 김외숙 인사 수석 동일인 인지 법무법인 부산 에서 공증 담당 변호사 누구 인지 수사 규명 해 달 권기정',
#  '부산 지방 법원 에서 시민 단체 회원 성폭력 피해자 정당방위 인정 해 달 촉구 성폭행 시도 려던 가해자 혀 깨물 었 다가 옥살이 최말 자씨 이날 만 재심 청구 연합뉴스 부산 지방 법원 에서 시민 단체 회원 성폭력 피해자 정당방위 인정 해 달 촉구 성폭행 시도 려던 가해자 혀 깨물 었 다가 옥살이 최말 자씨 이날 만 재심 청구 연합 성 폭행 려는 가해자 혀 깨물 었 다가 중상해죄 옥살이 여성 만 정당방위 인정 해 달 라며 법원 재심 청구 성폭력 피해자 인 최말 자씨 부산 여성 전화 여성 시민 단체 함께 오후 시 부산 연제구 거제동 부산 지법 정문 에서 성폭행 피해자 정당방위 인정 위한 재심 개시 촉구 회견 열 었 최 재심 청구 앞서 사법 변하 으면 후세 까지 피해 이어질 겠 다는 절박 자리 섰 밝혔 저 억울 함 풀리 정당방위 인정 돼 무죄 바란다 며 법 변화 돼 후손 오점 남겨서 절대 된다고 최 세 던 월일 저녁 성폭행 시도 던 당시 세 노모 혀 깨물 어 가량 자른 혐의 중상해죄 이듬해 부산 지법 에서 징역 집행유예 선고 았 재판 과정 에서 최 개월 간 옥살이 최 당시 검찰 강압 인 수사 견디 며 정당방위 였 주장 지만 법원 인정 았 검찰 최 노 상해 입혔 다며 조사 첫날 아무런 고지 없이 구속 검찰 노 강간 미수 혐의 적용 았 특수 주거 침입 혐의 만 기소 재판 부도 피고 결혼 해서 는가 되묻 심각 차 가해 재판부 판결문 에서 범행 장소 불과 거리 범행 장소 에서 지르 면 충분히 주변 들릴 었 다며 혀 깨문 최 행위 방위 지나친 판단 언론 키스 벙어리 혀 자른 키스 남성 마치 피해자 인 처럼 보도 사건 이후 오히려 주변 에서 결혼 면 간단히 끝나 느냐며 노 결혼 권했 최 에선 가시나 때려 죽인다고 난리 였 회상 반면 가해자 인 노 사건 이후 최 찾아와 흉기 책상 꽂 행패 부렸 결국 최 아버지 노 돈 합의 최 미투 운동 한창 용기 부산 여성 전화 상담 진행 올해 재심 청구 결심 이날 부산 여성 전화 피해자 가족 냉대 마을 손가락 질 견뎌 며 하루하루 고통 아야 다며 이제 라도 정당방위 외쳤 던 피해자 억울 함 풀 인권 회복 며 여성 방어 권 인정 성폭력 사건 정의 로운 해결 재심 개시 강력 게 요구 한다고 밝혔 권기정',
#  '창원 통합 창원시 대한 재정 특례 연장 필요 다는 주장 나왔 습니다 오늘 창원 컨벤션 센터 에서 열린 창원시 통합 평가 대 토론회 에서 참석자 창원시 재정 여력 판단 재정 자 주도 상대 축소 됐 다며 교부세 추가 확보 필요 평가 습니다 조미령',
#  '창원 거창 법조 타운 원활 추진 민관 협의회 오늘 출범 습니다 거창군 주민 대표 명과 거창군 의원 언론인 군 관계자 위원 꾸린 거창군 민관 협의회 출범 밝혔 습니다 협의회 거창 구치소 신축 인센티브 발굴 주민 친화 신축 방안 논의 계획 입니다 조미령',
#  '지난 현지 레바논 수도 베이루트 모스크 에서 신종 코로나 바이러스 감염증 코로나 막 위한 방역 작업 진행 연합뉴스 지난 현지 레바논 수도 베이루트 모스크 에서 신종 코로나 바이러스 감염증 코로나 막 위한 방역 작업 진행 연합뉴스 모스크 에서 마스크 착용 악수 카이로 연합뉴스 노재현 특파원 지중해 연안 국가 레바논 신종 코로나 바이러스 감염증 코로나 사태 문 닫 았 던 모스크 이슬람 사원 교회 예배 점진 허용 레바논 매체 데일리 스타 현지 보도 무함마드 파흐 미 레바논 내무부 장관 이날 금주 부터 금요일 일요일 모스크 교회 예배 허용 한다고 발표 이슬람교 신자 보통 금요일 모스크 에서 단체 기도 며 기독교 인 일요일 교회 에서 기도 한다 레바논 내무부 모스크 교회 문 열 지만 수용 가능 인원 만 개인 간 거리 두기 위생 지침 지켜야 한다고 강조 레바논 이슬람 수니파 종교 기관 이날 파트 이슬람 율법 해석 통해 신자 모스크 에서 기도 마스크 장갑 착용 서로 악수 아야 한다고 밝혔 여성 노약자 환자 어린이 모스크 예배 허용 는다 레바논 이슬람 수니파 시아파 마론파 기독교 종파 다양 모자이크 국가 불린다 레바논 당국 최근 코로나 확산 세 진정 자 각종 제한 조처 단계 완화 식당 미용실 영업 재개 다일 레바논 보건부 면 전국 에서 코로나 누적 확진 자 사망 레바논 에서 신규 확진 자 지난달 부터 계속 자릿수 기록 며 증가세 게 둔화',
#  '국판 홀로코스트 국가 결자해지 라 형제 복지 생존자 최승우 서울 여의도 국회 의원 회관 출입문 층 지붕 에서 과거 사법 개정안 통과 요구 며 시위 권도현 국판 홀로코스트 국가 결자해지 라 형제 복지 생존자 최승우 서울 여의도 국회 의원 회관 출입문 층 지붕 에서 과거 사법 개정안 통과 요구 며 시위 권도현 형제 복지 사건 국판 홀로코스트 라 불리 인권 유린 사건 누적 인원 만 이상 부터 까지 부산 사상구 주례동 형제 복지 부랑아 선도 한다는 명목 상 불법감금 됐 지난 오후 시분 쯤 대 남성 국회 의원 회관 출입문 층 지붕 올랐 제 이야기 어 시 라고요 수척 얼굴 국회의원 본 국회 경호 경비 직원 당황 해 며 잇 못했 직원 얼굴 익히 었 남성 정체 형제 복지 생존자 인 최승우 국가 폭력 대한 진상 규명 피해자 명예 회복 요구 며 이날 째 국회 에서 농성 진실 화해 위한 과거 사정리 기본법 일부 개정 법률안 과거 사법 국회 통과 주장 며 째 부터 고공 농성 시작 통화 면서 최 이번 국회 마지막 본회의 이번 다음 밖에 남 았 절박 심정 중학교 학년 경찰 반 끌려갔 습니다 형제 복지 에서 세 될 까지 았 어요 형제 복지 때려 죽이 곳 라는 소문 돌 자 아버지 찾 으러 셨 더군요 최 생존자 라 불리 건 그곳 에서 최 달리 죽 형제 복지 운영 된 동안 확인 된 사망자 수만 강제 노역 구타 살인 암매장 자행 됐 다는 증언 지만 실제로 얼마나 많이 죽 었 는지 피해 었 는지 진상 온전히 규명 았 과거 사법 개정안 대 국회 통과 못했 최 대 국회 다를 거 라 믿 었 믿음 국회 행정 전위 법제사 법위 문턱 마다 번번이 무너졌 각종 개혁 법안 패스트 트랙 신속 처리 안건 지정 올려져 통과 던 지난해 국회 에서 과거 사법 본회 통과 법안 이름 올리 못했 대 국회 민주당 야당 라는 이유 라도 었 죠 대 에선 여당 았 습니까 진선미 의원 의원 개인 도움 많이 줬 죠 형제 복지 사건 해결 시급 다고들 어요 하지만 당 차원 에서 움직임 습니까 형제 복지 특별법 통과 요구 며 시작 된 단식 지난해 과거 사법 개정안 통과 요구 이번 단식 까지 세 째 최 정부 믿 어렵 문재 인 대통령 당시 민주당 대표 자격 형제 복지 피해자 국회 증언 참석 기억 과거사 대 공약 세 째 앞세웠 잖아요 대통령 나서 형제 복지 사건 과거 사법 언급 더군요 지난달 총선 민주당 석 거대 여당 됐 지만 최 불안 매번 그랬 잖아요 해준다고 다가 못해 준 다가 됐 어요 내년 면 대선 국면 들어서 습니까 그러면 민생 법안 물 건너가 거 죠 불안 분노 이어졌 대 국회 종료 앞두 급하 게 고공 농성 시작 이유 됐 최 과거 사법 통과 피해자 어 줄 거 형제 복지 에서 폭력 살인 강간 인간 악덕 만 마주 어요 사춘기 시절 경험 제 남 았 죠 그때 부터 저 짐승 입니다 배우 못한 짐승 요 최 피해자 일부 짐승 인 게 부끄러워 세상 밖 국가 명예 회복 시켜 으면 계속 상태 거 짐작 세상 밖 나와 트라우마 치료 으면서 점점 어요 국가 만든 짐승 입니다 만드 국가 해야 겠 습니까 최 과거 사법 국회 통과 형제 복지 해결 면 배우 부터 연극 무대 서 며 인권 연극 참여 형제 복지 해결 싸우 면서 선감 학원 서산 개척단 국가 폭력 피해 생존자 트라우마 극복 도록 돕 꿈 생겼 혼자 힘 만 됩니다 국가 법 도와 줘야 합니다 그러면 피해자 나서 서 피해자 돕 과정 겁니다 조문희 박홍두',
#  '창원 사천시 오늘 부터 일부 관광 시설물 운영 합니다 사 천 비토 섬 국민 여 캐 핑장 일반 야영장 외 글 램 핑 스토리 하우스 모든 시설물 운영 시작 됩니다 사 천 만남 광장 관광 안내소 문화 관광 해 설사 곳 문 엽 니다 사 천 시 관광 시설물 집단 방역 이용자 마스크 착용 권유 계속 계획 입니다 최진석',
#  '창원 진주시 코로나 여파 유치원 어린이 천 백 여 간식 꾸러미 보냅니다 진주시 지난 달 동안 쓰 못한 간식 지원 비 천 백 여 만 들여 유치원 곳 어린이 천 백 여 간식 꾸러미 보낸다고 밝혔 습니다 최진석',
#  '문 연 국립 중앙 박물관 입장 기다리 시민 오전 서울 용산구 국립 중앙 박물관 찾 시민 떨어져 서 서 전시관 입장 기다리 국립 중앙 박물관 생활 거리 두기 시작 된 이날 부터 문 열 었 김지호 문 연 국립 중앙 박물관 입장 기다리 시민 오전 서울 용산구 국립 중앙 박물관 찾 시민 떨어져 서 서 전시관 입장 기다리 국립 중앙 박물관 생활 거리 두기 시작 된 이날 부터 문 열 었 김지호 재택근무 끝 판교 직장인 마스크 출근 행렬 오전 경기도 성남시 판교역 인근 에서 마스크 쓴 직장인 출근 이날 거리 두기 종료 며 그간 재택근무 실시 던 판교 인근 업체 단계 정상 출근 들어갈 방침 고운 호 재택근무 끝 판교 직장인 마스크 출근 행렬 오전 경기도 성남시 판교역 인근 에서 마스크 쓴 직장인 출근 이날 거리 두기 종료 며 그간 재택근무 실시 던 판교 인근 업체 단계 정상 출근 들어갈 방침 고운 호 코로나 바이러스 감염증 대한 방역 체계 거리 두기 에서 생활 거리 완화 짧 게 여일 길 게 여일 문 닫 았 던 국립 박물관 미술관 문 열 었 모처럼 민간 실내 상업시설 활기 돌 았 하지만 공공시설 가운데 서 운영 주체 따라 문 여 곳 곳 공지 없이 엇갈리 면서 방문객 헛걸음치 사례 나왔 비 현실 인 정부 방역 지침 대한 불만 인한 혼선 곳곳 에서 빚어졌 오후 시 쯤 서울 성북구 종암동 헬스 장 남자 샤워실 에서 운동 마친 남성 샤워 었 이날 부터 시행 된 정부 생활 거리 두기 지침 헬스 장 체육 시설 이용 샤워 장 이용 권고 한다 손님 정보 전하 자 냐 몰랐 홍모 어차피 땀 묻 헬스 기구 함께 쓰 그건 괜찮 멀찌감치 떨어져 샤워 건 된다는 근거 뭐 냐며 여기 서 분 거리 인데 꼭 서 샤워 바 그냥 계속 헬스 쉬 겠 오전 시 서울 용산구 국립 중앙 박물관 정문 열렸 문 닫 이후 만 었 박물관 입구 향하 길바닥 간격 빨간색 구두 발자국 모양 스티커 붙 어 었 입장객 여 각각 스티커 위 에서 순서 기다렸 시민 실내 에서 의식 이상 거리 유지 며 관람 시설 마다 온라인 예약 통해 거리 유지 가능 선 에서 만 입장객 았 마스크 쓰 손 님 았 방문객 김 모 그동안 문화 생활 어 섭섭 아파트 커뮤니티 시설 모처럼 활기 띠 었 서울 서초구 반포동 아파트 정부 방역 체계 전환 맞춰 단지 골프 연습장 열 어 달 라는 민원 이어진 끝 이날 오전 문 열 었 대신 출입구 통일 뒤 발열 체크 방문 기록부 작성 의무 화 화성시 동탄 신 도시 아파트 에서 커뮤니티 시설 재가동 앞두 주민 간 아이 개교 시기 맞춰서 열자 아파트 호수 홀짝 수제 도입 자 토론 활발 게 벌어졌 하지만 탁상행정 결과물 가까운 정부 일부 지침 지탄 대상 됐 이날 오전 시 당산역 지나 지하철 호선 전동차 내부 몸 움직일 빽빽 그간 상당수 기업 직원 출퇴근 조정 유연 근무 제 시행 지만 이날 부터 대부분 오전 시 출근 돌아갔 회사원 박모 지침 면 만 지하철 그냥 보내 타 라는 출근 그게 냐고 서울 상수동 미용실 원장 김 모 미용실 시설 의자 간격 규정 코웃음 쳤 벽 붙여 거울 맞춰 의자 배치 뜯어내 인테리어 새로 라는 거 냐며 마나 현장 선 혼선 빚어졌 오후 시 서울 여의도 성모병원 장례식장 얼굴 새빨개 진 대 조문객 서로 배웅 며 포옹 나누 었 이날 마련 된 빈소 세 곳 모두 여 조문객 었 장례식장 측 지침 따라 입장 시 이름 전화 번호 인 사항 기재 체온 체크 후 마스크 쓰 도록 철저히 관리 었 하지만 개별 빈소 달랐 지침 조문객 분 이내 조문 조의금 전달 온라인 뱅킹 이용 권고 지만 조의금 봉투 없이 조문 찾 어려웠 분 넘 게 머무 았 비슷 시각 용산구 한남동 주점 선 테이블 마다 손 님 모여 찌개 나눠 먹 었 석 규모 가게 손 님 여 여유 었 지만 지그재그 앉 거나 자리 띄워 앉 모습 볼 었 정부 생활 거리 두기 세부 지침 음식점 카페 포장 배달 판매 활성 화 안내 한다 사장 신모 면 배 달집 만 살아남 왜 월세 영업 냐 답답 라며 모든 손 님 한테 반찬 인분 씩 따로 나눠 려면 식 새로 사 야 설거지 가뜩이나 코로나 힘들 게 버텨왔 그냥 망하 라는 얘기 냐고 다지 자체 관리 공공시설 가운데 이날 문 열 곳 았 이날 낮 서울 관악구 용 꿈꾸 작 도서관 에서 굳 게 닫힌 정문 에서 주민 도영 택 발길 돌렸 도씨 에서 오늘 부터 도서관 개관 한다고 해서 봤 이전 부터 단골 이용 던 곳 라 궁금 해서 왔 따로 공지 건 었 서울 종로구 코인 노래방 에서 이날 오전 알바 생 엎드려 자 사이 손님 방명록 작성 드나들 었 노래방 구청 으로부터 새로운 지침 게 오전 강남구 방 실내 곳곳 좌석 씩 띄 어 앉 마스크 착용 필수 안내문 붙 었 지만 손 님 마스크 쓴 불과 직원 손 님 띄워 앉 강요 거나 마스크 씌울 순 거 냐고 최 아리 유종헌 허유진 조선일보',
#  '창원 앵커 지난 코로나 소상 공인 주름살 깊 어 질 임대료 깎 착한 임대료 운동 벌어졌 는데요 경상남도 전국 에서 처음 임대료 내린 건 물주 지방세 감면 해 보답 조례 었 습니다 경남 시군 모두 동참 습니다 천 현수 보도 입니다 리포트 창원 전통 시장 식당가 점포 여러 가진 이복 화씨 지난 부터 세입자 임대료 내려서 습니다 코로나 확산 손 님 끊 어 다시피 자 세입자 고통 나누 위한 결정 었 습니다 복화 음정 시장 상가 주인 같이 어려우 니까 만 어려운 게 잖아요 그래서 같이 함께 저희 동참 동기 됐 습니다 임대료 수입 달 총 만 에서 인 만 천 줄 었 습니다 대신 부과 재산세 만 천 에서 만 천 감 면 게 됐 습니다 지난달 의회 통과 지방세 감면 조례 덕분 입니다 경남 시군 모두 이달 관련 조례 통과 시켜 착한 임대인 운동 참여 도민 보답 예정 입니다 창원 김해 시군 주민세 최대 깎 줄 예정 입니다 포함 임대료 에서 깎 준 비율 만큼 지방세 감면 해 방식 입니다 백종철 경상 남 세정 과장 정부 일부 지원 건물 주도 지원 형태 해서 소상 공인 지원 정책 시 면 됩니다 경상남도 착한 임대료 운동 동참 이어져 다음 달 까지 재산세 경감 대상 전체 만 건 될 습니다 각 시군 부터 다음 달 까지 건물 신청 재산세 감면 절차 시작 합니다 천 현수 입니다 천 현수',
#  '창원 생활 거리 전환 따라 경남 지역 도서관 체육 시설 박물관 오늘 부터 차례 문 엽 니 경상남도 오늘 경남대 표 도서관 부분 개관 해 일반 자료실 어린이 자료실 이용 창원시 시군 도서관 오늘 곳 곳 차례 문 연다고 밝혔 습니다 국립 진주 김해 박물관 오늘 전시실 부분 개관 들어가 경남 지역 박물관 곳 가운데 곳 개관 합니다 공공 체육 시설 곳 가운데 실외 시설 곳 개방 실내 시설 차례 문 엽 니다 천 현수',
#  '오전 정부세종청사 에서 중앙 재난 안전 대책 본부 브리핑 인 검 머리 김강립 보건복지부 차관 뉴시스 오전 정부세종청사 에서 중앙 재난 안전 대책 본부 브리핑 인 검 머리 김강립 보건복지부 차관 뉴시스 지난 오전 정부서울청사 에서 중앙 재난 안전 대책 본부 브리핑 인 흰머리 김강립 차관 연합 지난 오전 정부서울청사 에서 중앙 재난 안전 대책 본부 브리핑 인 흰머리 김강립 차관 연합 지난 동안 정부 중앙 재난 안전 대책 본부 대본 입 역할 맡 브리핑 해 왔 던 김강립 보건복지부 차관 염색 나타났 나날이 뿌리 께 희끗희끗 해 머리 기자단 사이 에서 코로나 바이러스 감염증 유행 장기 화 상징 라는 나왔 생활 거리 두기 첫날 맞 깔끔 검 머리 변신 오전 세 종시 보건 복지 부 청사 층 브리핑 룸 에서 생활 거리 두기 첫날 맞 대면 브리핑 약 주만 열렸 지난 주간 거리 인해 중대 본 브리핑 온라인 진행 됐 이날 달라진 대면 브리핑 만 었 브리핑 단상 올라선 김강립 차관 지난 코로나 첫 브리핑 당시 검 머리 돌아간 모습 었 김 차관 브리핑 직후 어머니 께서 얼굴 직접 못 더라도 화면 제발 염색 나와라 아들 늙 어 다면서 어제 서 야 서 변신 었 코로나 사태 터지 부터 어머니 찾아뵙 다면서 머리 흰 모습 어머니 속상해 시 제 효자 지만 해야 겠 었 김 차관 지난 가량 브리핑 자리 비우 코로나 확진 판정 경기 성남 분당 제생 병원장 병원장 간담회 에서 접촉 면서 자 격리 대상 됐 던 격리 요리 다채 롭 게 해 면서 처음 하루 세 끼 사진 찍 어서 아내 한테 보냈 다면서 요리사 직업 택하 건 한다고 격리 마지막 날 드라이브 스루 진단 검사 결과 음성 판정 다음 날 부터 출근 김 차관 거리 두기 끝나 일상 생활 거리 두기 시작 된 이날 코로나 전문가 처음 겪 질병 라 현재 상황 안심 을지 겠 다면서 살얼음판 걷 기분 김 차관 총선 에서 단 감염자 뿌듯 꼽 으며 국민 대단 자부심 느껴도 된다고 허 상우 조선일보',
#  '창원 앵커 특수 학교 학교 별 여건 고려 해 자율 등교 개학 도록 돼 는데요 언제 등교 개학 시작 될지 정해 상황 에서 특수 학교 교사 학생 온라인 수업 소통 고군분투 습니다 조미령 보도 입니다 리포트 유치 부 에서 초 중고 전공 반 까지 전교 생 규모 사립 특수 학교 입니다 화상 수업 시작 자 초등 반 선생 님 학생 표정 점검 며 인사 합니다 생긴 장민규 선생 님 에요 학생 이름 부르 질문 던지 면서 수업 집중력 높 입니다 건우 경찰차 본 나요 시윤 장민규 창원 동백 학교 교사 특별 지침 어서 학교 자체 에서 지침 수립 어려운 었 지만 극복 선생 님 노력 해서 원격 수업 해 학생 소통 았 습니다 등반 학생 화면 통해 선생 님 얼굴 마주 수업 듣 습니다 화재 발생 피해 대처 방법 대해 봤 오늘 수업 어땠 어요 았 어요 장애 따라 일방 인 동영상 강의 학습지 과제 수업 진행 어려워 쌍방향 화상 수업 해야 합니다 정창원 동백 학교 교사 쉽 게 이해 도록 자세 게 설명 그림 자료 동영상 통해서 전달 도록 노력 습니다 유 치부 학생 관심 끌 위한 인형극 연출 해 동영상 보내 과제물 따라 도록 영상 담 습니다 친 밀도 높이 생일 맞 학생 보낼 축하 영상 제작 습니다 일반 학교 달리 학습 콘텐츠 부족 정규 프로그램 조차 특수 학교 맞춤 형 수업 위한 선생 님 열정 온라인 수업 사각지대 극복 습니다 조미령 입니다 조미령',
#  '창원 앵커 고등학교 학년 부터 등교 개학 시작 는데요 만약 학교 에서 코로나 증상 자 면 어떻게 대처 해야 할까요 모의 훈련 현장 배수영 다녀왔 습니다 리포트 등교 던 초등학생 체온 까지 오릅니다 도네 보건 용 마스크 새로 줄 테 니 이걸로 바꾸 자 수업 기침 계속 학생 습니다 열 네 불편 곳 니 담임 교사 곧장 학생 학교 일시 관찰 실로 이동 시킵니다 이어 보호자 연락 해 학생 선별 진료소 도록 안내 합니다 다음 날 해당 학생 코로나 확진 판정 자 모든 학생 교직원 자 격리 들어가 원격 수업 바뀝니다 유동 김해 관동 초 교사 확진 자 발생 면 방역 당국 역학 조사 따라 격리 건물 폐쇄 여부 결정 합니다 고등학교 학년 부터 시작 등교 개학 앞두 코로나 확진 자 발생 가정 모의 훈련 입니다 박종훈 경상 남 교육감 코로나 대응 모의 훈련 해서 관련 동영상 제작 해 안내 합니다 당분간 학교 에서 점심 제외 모두 마스크 써야 합니다 경상남도 교육청 학생 인 당 각 장 씩 만 장 마스크 배부 습니다 반 초등 학교 중학교 넘 반 나눠 운영 급식소 칸막이 설치 간격 유지 대책 세우 습니다 에서 학생 증상 면 학부모 바로 담임 교사 알려야 교사 학생 등교 중지 건강 관리 안내 해야 합니다 배수영 입니다 배수영',
#  '정재현 부천시 의회 행정 복지 위원장 정재현 부천시 의회 행정 복지 위원장 서울 신문 경기 부천 시 에서 장애 인 편의 시설 점검 시 유형 별 장애인 직접 점검 당사자주의 실현 된다 부 천 시 의회 행정 복지 위원회 정재현 위원장 부천시 면 최근 부천시 의회 내용 포함 부천시 장애 인 복지 증진 위한 기본 조례 일부 개정 조례 의결 까지 부 천 시 장애 인 편의 시설 점검 부천시 담당 공무원 명과 기술 지원 센터 직원 해당 시설 장애 인 명만 참여 해 왔 현재 지체 뇌 병변 시각 청각 언어 장애 유형 모두 현실 비춰 면 매우 부족 장애 인 시설 편의 성 높이 점검 시 유형 장애 인 여러 위촉 해 가능 장애 인 모두 불편 없이 시설 이용 도록 한다는 게 이번 조례 개정 내용 다이 개정 된 부천시 장애 인 복지 증진 위한 기본 조례 개정 내용 조 항이 추가 됐 추가 된 내용 시장 시 소속 공무원 장애 인편 증진 센터 직원 부천 시 주소 둔 장애 인 점검 요원 위촉 다만 점검 요원 장애 인 이상 인 장애 유형 달리 다는 다이 앞서 지난 부천 시 시작 장애인협회 고대 천 회장 비롯 여 부천 시민 장애 인편 시설 각 장애 인 특성 별 장애인 점검 도록 유형 별 장애인 직접 참가 당사자주의 실현 도록 조례 개정 해 달 라는 청원 었 김환석 의원 시각 장애 인 위한 점자 표지판 방향 바뀐 다며 부분 에서 점자 확인 가능 분 직접 확인 해서 불 합리 안내 바로잡 아야 한다고 밝혔 이번 개정 조례 정재현 부천시 의원 대표 발의 박병권 김환석 김성용 윤병권 홍진아 구점 자 송혜숙 권유경 강병일 김주삼 의원 함께 참여 정재현 행정 복지 위원장 코로나 긴 지만 우연히 장애인 날 즈음 해 장애인 권익 증진 조례 대표 발의 개정 마무리 해 대단 영광 한다고 밝혔 이명선 서울 신문',
#  '서울시 현대차 그룹 신 사옥 글로벌 비즈니스 센터 착공 허가 이르 면 강남구 삼성동 국내 최고 층 건물 들어선다 서울시 이날 현대차 그룹 신축 사업 착공 신 고서 수리 착공 신고 필 증 교부 다며 인허가 절차 최종 마무리 됐 밝혔 현대차 강남구 영동대로 옛 한국전력 부지 만 조억 사들이 며 사업 본격 시작 현대차 하반기 준공 목표 이달 착공 한다는 지하 층 지상 층 규모 업무 시설 관광 숙박 시설 공연장 전시장 문화 집회 시설 판매 시설 어서 대 규모 복합 시설 높이 잠실 롯데월드 타워 보다 높 국내 최고 층 최상층 부인 층 전망대 쓰일 예정 서울시 공사 시 안전 보건 환경 종합 대책 수립 해 시행 교통 대한 종합 인 대처 방안 강구 겠 다며 기술자 문단 꾸려 안전사고 재난 상황 종합 대비 주변 교통 체증 방지 교통 대책 태 스 포스 운영 예정 밝혔 허남 설',
#  '인천시 저 신용 담보 어 금융 권 에서 대출 신용 불량자 저금리 돈 빌려 사업 시행 다인 천 시 과도 채무 법원 이나 신용 회복 위원회 에서 채무 조정 신용 불량자 돕 부터 인천 어진 론 실시 한다고 밝혔 인천 어진 론 코로나 사태 어려워진 경제 상황 에서 금융 권 에서 대출 조차 신용 불량자 이내 저금리 만 미만 소액 대출 해 사업 인천시 억 예산 긴급 편성 대상 신용 회복 위원회 채무조정 확정 후 개월 이상 또는 법원 개인 회생 인가 후 이상 원금 이자 성실 게 납부 신청 이날 부터 신용 회복 위원회 면 된다 인천 약 만 신용 불량자 대출 돈 생활비 임차 보증금 생활 안정 자금 이나 학자금 고금리 채무 이용자 차환 자금 영세자 영업자 운영 자금 사용 면 된다 인천시 관계자 신용 불량자 금융 권 에서 대출 못 대부 업체 에서 고금리 사채 사용 다며 코로나 사각지대 놓인 조금 이나마 도움 인천 어진 론 시행 게 됐 박준철',
#  '코로나 방역 체계 생활 거리 전환 된 서울 마포 중앙 도서관 에서 시민 개인 소독 후 입장 기다리 연합뉴스 코로나 방역 체계 생활 거리 전환 된 서울 마포 중앙 도서관 에서 시민 개인 소독 후 입장 기다리 연합뉴스 서울 인천 경기 수도 권 지자체 정부 코로나 대비 물리 거리 두기 생활 거리 전환 면서 박물관 미술관 도서관 공공시설 개방 다만 사전 예약 제 도입 해 관람 인원 제한 차츰 정상 화 어린이 노인 주로 이용 일부 공공 시설 아직 이르 다는 판단 개방 일정 미루 곳 서울시 직접 관리 운영 공공시설 서울 역사박물관 서울 시립 미술관 문화 시설 서울시 공공 서비스 예약 시스템 에서 선착순 접수 해 입장 허용 관람 이내 입장 가능 인원 시설 규모 따라 제한 된다 서울 도서관 온라인 예약 대출 이용 부터 자료실 개방 부터 방문 허용 이용 가능 열람 석 절반 제한 예정 세종문화회관 남산 예술 센터 공연장 관람석 제한 뒤 단계 확대 실내 체육 시설 이용자 신상 파악 가능 강습 훈련 부터 정원 절반 한정 해 운영 재개 한다 목동 빙 상장 이날 개장 잠 실수 영장 부터 문 연다 동네 키움 센터 지역 아동 센터 초등 돌봄 시설 학교 개학 맞춰 이후 개원 예정 어린이집 영아 면역력 취약 다는 고려 해 개원 시기 검토 연로자 시설 인 노인 종합 복지 관 경로당 운영 재개 보류 종합 복지 관 어르신 주야간 보호 시설 장애 인 직업 재활 시설 장애 인 주간 보호 시설 부터 소규모 비 접촉 성 프로그램 중심 일부 운영 시작 인천 이날 부터 공공시설 부분 개방 도서관 열람실 자료실 휴관 당분간 유지 회원 가입 도서 예약 통한 대출 만 가능 월일 부터 도서관 박물관 비롯 해 영화 상영관 모든 시설 전면 개방 예정 서구 수도 권 매립지 관리 공사 인조잔디 축구장 인라인 트랙 배구 농구 테니스장 문화 체육 시설 개방 경기도 공공시설 역시 속속 개장 한다 수원시 수원 수원 광교 수원 화성 박물관 이날 개관 관람 인원 당 제한 단체 관람 실시 는다 경기도 미술관 경기도 박물관 백남준 아트 센터 실학 박물관 전곡 선사 박물관 곳 부터 정상 운영 경기도 어린이 박물관 문 열 예정 며 경기 북부 어린이 박물관 개관 시기 아직 정하 았 화성시 게이트볼 장 이나 국궁 장 야외 체육 시설 도서관 부터 단계 개장 오토캠핑 장 다음 달 쯤 개장 실내 체육 시설 이나 수영장 경로당 당분간 휴관 조치 어 갈 방침 허남 설 박준 철경 태영',
#  '대구시 교육부 방침 달리 각급 학교 등교 시점 조정 발표 해 교육 현장 혼란 빚어지 대 구 시 교육청 면 권영진 시장 전날 대 시민 담화문 에서 코로나 확산 된 대구 상황 맞 게 등교 일정 조정 방안 시 교육청 협의 해 나갈 밝히 면서 학교 교육청 학부모 실제 개학 날짜 문의 이어지 앞서 교육부 부터 고을 시작 순차 등교 한다고 발표 고중 초 고중 초 중초 월일 등교 하지만 권 시장 발언 교육부 방침 달리 대구 등교 시점 자체 조정 음 시사 해 혼란 불러일으키 실제로 권 시장 발표 직후 지역 교육청 학교 언제 부터 등교 느냐는 문의 빗발쳐 해명 느라 진땀 빼 아들 딸 둔 김정숙 수성구 민감 중요 등교 시점 교육부 따로 대구시 따로 면 누구 믿 어야 느냐면서 가운데 대구시 교육청 적극 목소리 게 의아 스럽 대구시 민감 등교 시점 발표 면서 대구시 교육청 사전 협의 았 다는 인해 대구시 교육청 당혹감 감추 대구시 교육청 아직 교육부 방침 에서 변경 된 다면서 대구 지역 만 등교 연기 가능 한지 여부 교육부 질의 해 상태 밝혔 박태우',
#  '광주시 학교 밖 청소년 장학금 지급 도록 관련 규정 개정 학교 밖 청소년 장학생 선발 대상 에서 제외 차별 라는 시민 단체 지적 받아들인 광주시 학교 다니 학교 밖 청소년 장학금 지급 도록 빛 장학 재단 정관 개정 계획 밝혔 빛 장학 재단 정관 장학생 선발 대상 학교 재학 인 자 규정 인해 그동안 학교 밖 청소년 장학생 선발 대상 에서 제외 돼 왔 빛 장학 재단 지난해 광주 지역 고대 학생 여명 억만 장학금 지급 광주시 올해 빛 장학 재단 이사회 통해 정관 장학금 지급 규정 개정 해 내년 부터 학교 밖 청소년 장학금 지급 계획 시민 단체 그동안 학교 밖 청소년 장학금 지급 대상 에서 제외 차별 지적 해 왔 학벌 위한 시민 모임 광주 대안 교육 협의회 학교 밖 청소년 지원 제한 차별 라며 시정 촉구 단체 어려운 가정 환경 에서 학업 자기 계발 의지 강한 학교 밖 청소년 수업 경비 진로 탐색 개발비 학업 장려금 지원 도록 장학생 선발 대상 확대 해야 한다고 주장 다손 옥수 광주시 청년 청소년 과장 장학금 취지 인재 양성 인 만큼 학교 밖 청소년 지원 게 옳 판단 돼 규정 개정 설명 강현석',
#  '서울 송파구 보건소 관계자 잠 고교 급식 실 에서 학생 등교 대비 해 방역 작업 연합뉴스 서울 송파구 보건소 관계자 잠 고교 급식 실 에서 학생 등교 대비 해 방역 작업 연합뉴스 전국 시도 교육청 순차 등교 수업 앞두 식당 칸막이 설치 거나 좌석 넓 게 조정 코로나 감염 막 위한 다양 급식 대책 내놓 충북 교육청 순차 등교 계획 따라 도내 유초 특수 학교 전체 에서 급식 한다고 밝혔 학교 곳 식당 에서 곳 교실 에서 급식 실시 한다 학교 식당 교실 에서 동시 급식 한다 도내 인 학교 정상 급식 예정 충북 교육청 정상 급식 힘든 학교 간 편식 제공 권유 간 편식 볶음밥 카레 라이스 짜장면 덮밥 일품요리 반찬 가짓수 적어지 면 배식 줄어들 어 학생 간 접촉 최소 화 급식 인원 이상 인 학교 초 칸막이 설치 권장 학교 식당 칸막이 설치 상태 나머지 학교 학생 간 간격 유지 도록 좌석 배치 급식 조정 시차 배식 한다 학교 시차 배식 좌석 조정 교실 배식 학교 교실 에서 급식 진행 한다 대전시 교육청 학교 여건 따라 급식 실 에서 줄 이나 지그재그 형태 엇갈리 게 앉 식사 게 좌석 조정 임시 칸막이 설치 조치 도록 배식 최대한 분산 해서 도록 수업 조정 급식 탄력 운영 한다 여건 상 급식 불 가능 대 체식 제공 이나 도시락 지참 가능 도록 충남 교육청 학생 간 접촉 최소 화 줄 식사 대책 마련 급식 교사 학생 같이 이동 면서 손 소독 식사 대화 음식 나눠 먹 지도 다경 남 교육청 최근 코로나 감염 예방 관리 가이드북 관련 영상 경남 지역 전체 학교 안내 가이드북 등교 등교 시 등교 후 급식 나눠 상황 별 대응 방법 담겨 억 예산 지원 해 학교 식당 칸막이 설치 도록 점검 마친 상태 충북 교육청 관계자 코로나 확산 막 손 씻 줄 서기 학생 대상 사전 교육 철저히 계획 라며 코로나 이후 급식 진행 처음 라 학교 현장 혼란 스러울 예상 지만 부족 바로 보완 해 학생 불편 함 도록 겠 이삭 김정훈 이종섭 권순재',
#  '세 종시 마권 장외 발매소 화상경 마장 유치 검토 시민 사회단체 중심 시민 게 반발 세 종시 아파트 입주자 대표 연합회 세종 시민 사회단체 연대 회의 세종 여성 시민 사회단체 세종 시청 에서 회견 열 세수 증대 혈안 돼 반 교육 미래 지향 인 도시 역행 사행 산업 유치 려는 세 종시 이해 다며 화상경 마장 유치 검토 철회 촉구 시 화상경 마장 유치 절차 설치 장단점 파악 뒤 관련 사업 추진 대한 여론 살피 시 화상경 마장 유치 연간 억 세수 증대 규모 일자리 창출 효과 기대 한다 화상경 마장 추진 세 종시 외곽 놀이 시설 포함 공원 형 조성 겠 다는 게 시 복안 민사회 단체 도심 외곽 화상경 마장 설치 문화 공간 조성 시민 여가 공간 될 라는 시 주장 시민 삶 피폐 게 어 돈 세수 증대 겠 다는 불과 주장 주민 자치 조직 주민 모임 망라 범 시민 대책 기구 어 화상경 마장 막 낼 밝혔 이날 부터 화상경 마장 유치 반대 시민 서명 운동 시작 화상경 마장 경마 공원 서울 부산 경남 제주 에서 열리 경기 생 중계 시스템 경마 공원 에서 만 판매 마권 우승 마 예상 사 표도 화상 경마장 에서 구입 지만 화상경 마장 레저 아닌 도박 위한 경마 추구 곳 란 비판 는다 대전 에서 화상경 마장 개장 이후 주변 술집 마사지 숍 게임 장 유흥 사행 업소 밀 집지 바뀌 었 앞서 충남 보령시 홍성군 금산군 화상경 마장 유치 추진 다가 주민 반발 부딪혀 철회 권순재',
#  '서울 북부 지방 법원 유승관 서울 북부 지방 법원 유승관 서울 이상학 대 노모 폭행 현의 대 아들 구속 됐 서울 북부 지법 박지원 영장 전담 부장 판사 도주 우려 증거 인멸 우려 다며 대한 구속 영장 발부 서울 노원구 아파트 에서 함께 던 대 노모 폭행 혐의 는다 지난 요양 보호사 신고 경찰 어머니 몸 폭행 흔적 발견 수사 착수 어머니 경찰 조사 에서 아들 로부터 폭행 당한 진술 전해 졌으며 지난달 중순 폐렴 병원 에서 숨졌 서울 노원 경찰서 지난달 차례 대한 구속 영장 신청 했으나 검찰 어머니 사망 폭행 인한 인지 살펴보 라는 취지 영장 반려 경찰 어머니 폐렴 숨졌 판단 존속 상해 혐의 최근 구속 영장 신청 혐의 부인 전해졌 코리아',
#  '남양유업 경쟁사 비방 글 온라인 게시 정황 경찰 포착 해 수사 서울 종로 경찰서 홍원식 남양유업 회장 명예 훼손 혐의 입건 해 수사 밝혔 경찰 면 남양유업 지난해 초 홍보 대행사 동원 해 온라인 맘 카페 경쟁 업체 인 사 비방 내용 글 댓글 지속 해서 게시 혐의 경쟁 업체 측 여러 곳 맘 카페 업체 원유 납품 목장 근처 원전 방사능 유출 영향 냐는 내용 글 반복 올라온 확인 글 올린 아이디 특정 해 경찰 고소 전해졌 경찰 지난해 홍보 대행사 압수수색 해 해당 글 게시 아이디 여개 확보 앞서 남양유업 인터넷 경쟁사 비방 글 유포 혐의 경찰 수사 바 김준엽 국민 일보',
#  '청주 앵커 세계 인 코로나 대유행 이른바 펜데 믹 상황 충북 산 코 진단 키트 각국 수출 는데요 청주 둥지 튼 식 약 처 질병관리본부 지역 대학 의료 기관 협업 제품 개발 상용 화 큰 역할 다는 평가 입니다 황 주향 보도 합니다 리포트 여 중소기업 입주 오송 바이오 클러스터 식 약 처 질병관리본부 보건 의료 정부 기관 이전 면서 오송 업체 임상시험 승인 복잡 인허가 절차 허비 아도 됩니다 정원식 약 처 허가 총괄 팀장 추가 인 자료 라든가 요구 될 근처 니까 오송 거주 제약 기업 조금 수월 게 인허가 담당자 대 면 상담 실시 어서 학교 의료 기관 꾸준히 해온 공동 연구 장비 까지 공유 면서 개발 단축 됐 습니다 개발 필요 코로나 양성 검체 근처 충북 대 병원 에서 신속 게 전달 충북 대 약대 에서 검사 위한 장비 인력 근처 병원 에서 임상시험 센터 시설 지원 습니다 홍진태 충북 대학교 약학 대학 장 꾸준히 공동 연구 인 교류 거기 회사 학생 요 기술 같이 공유 기존 협력 체제 구축 어 었 충청북도 진단 장비 연구 개발 억 예산 배정 재정 지원 나섰 습니다 이재영 충북 북도 바이오산업 국장 기업 활동 시 면서 생산 활동 차질 생기 거나 어려운 신다면 분야 막론 해결 해 드릴 지원 티 에프 꾸려서 습니다 산 학관 연계 바이오 기술 경쟁력 갖춘 오송 감염병 대응 클러스터 발돋움 습니다 황주 향 입니다 황 주향',
#  '청주 앵커 거동 불편 장애인 이나 어르신 대중교통 이용 쉽 은데 요충 지역 시내 버스 승차장 승하차 돕 노선 안내 안전 도우미 배치 돼 호응 얻 습니다 이만영 입니다 리포트 시내버스 승차장 버스 진입 자 홍영숙 분주 해집니다 버스 에서 내리 어르신 부축 해 장 들렀 다가 어르신 보따리 챙기 잊 습니다 예 갑니다 잠깐 기다리 세요 주덕 차 제 태워 드릴게요 순환 노선 환승 복잡 만 버스 노선 안내 버스 승하차 도우미 몫 입니다 홍영숙 시내버스 승하차 도우미 배차 간격 차이 니까 많이 기다리 셔야 잖아요 그러니까 그분 힘드 시 잖아요 그럴 가장 안타깝 충주시 지난 고령자 장애 인 교통 약자 돕 주요 버스 정류장 승하차 도우미 배치 습니다 지역 교통 어두운 외지인 교통 안내 뿐 라 요 관광지 까지 알려 며 친절 도우미 역할 톡톡히 해내 습니다 이숙경 시내버스 승하차 도우미 여기 근교 터미널 잖아요 니까 외지인 여기 많이 방문 세요 니까 충주 대해서 그분 시 잖아요 승하차 안전사고 예방 큰 효과 평가 면서 올해 부터 도우미 배치 승차장 확대 장날 뿐 라 매주 월요일 추가 운영 습니다 권영학 충주시 교통 정책 주말 토요일 일요일 병원 휴무 으니까 이용 못 시 니까 그래서 월요일 병원 많이 이용 세요 어르신 께서 그래서 추가 게 됐 습니다 교통 약자 돕 시내버스 승차 도우미 따뜻 정 느낄 새로운 도심 풍경 습니다 이만영 입니다 이만영',
#  '동영상 앵커 아우디 어 벤츠 닛산 포르쉐 일부 경유 차량 배출 가스 프로그램 불법 조작 적발 돼 사상 최대 인 억 대 과징금 부과 됐 습니다 시동 걸 분 지나 면 불법 프로그램 작동 면서 배출 가스 기준치 최대 배 이상 확인 됐 습니다 신현준 보도 입니다 배출 가스 불법 조작 적발 된 차량 벤츠 닛산 포르쉐 경유 차량 종 만 여 대 입니다 벤츠 블 루 텍 종 만 천 여 대로 가장 닛산 캐시 카이 종 천 백 여 대 포르쉐 마칸 디젤 종 대 입니다 에서 사이 판매 된 입니다 조작 수법 습니다 인증 시험 달리 실제 주행 면 배출 가스 인 질소 산화물 물 질소 바꿔 기능 떨어지 거나 배출 가스 줄이 재순환 장치 작동 중단 된 겁니다 김영민 환경부 교통 환경 과장 차량 시동 걸 서 보통 분 지나 면 바로 요소 암모니아 수용액 사용량 중단 상황 배출 가스 거의 줄어들 는다고 봐야 될 습니다 벤츠 실내 인증 기준 최대 배 넘 질소 산화물 배출 됐 닛산 포르쉐 각각 기준치 배 배 초과 습니다 벤츠 배출 가스 불법 조작 국내 에서 적발 된 이번 처음 입니다 환경부 가장 차종 적발 된 벤츠 사상 최대 인 억 과징금 닛산 포르쉐 각각 억 억 과징금 부과 습니다 수입 차 배출 가스 불법 조작 적발 된 아우디 폭스바겐 이후 째 입니다 김영민 환경부 교통 환경 과장 상한 액 억 었 이후 상한 액 과징금 액수 너무 작 냐는 지적 어서 후 법 개정 습니다 적발 된 입사 이내 환경부 결함 시정 계획서 제출 해 승인 아야 이후 차량 소유자 리콜 즉 결함 시정 조치 습니다 신현준 입니다 당신 제보 됩니다 여러분 소중 제보 기다립니다 검색 해 채널 추가 전화 메일 온라인 제보 권 자',
#  '청주 앵커 충청북도 차례 고배 마셨 던 방사광 가속기 유치 도전 해 차 관문 통과 습니다 후보지 곳 가운데 청주 오창 정부 우선 협상 지역 곳 포함 됐 는데요 청주 지질학 안정 성 입지 조건 에서 평가 전해졌 습니다 진희정 입니다 리포트 미래 핵심 산업 최 첨단 연구 기반 시설 인 방사광 가속기 유치 충북 발 다가갔 습니다 오늘 대전 에서 열린 정부 심사 에서 우선 협상 대상지 가운데 곳 선정 됐 습니다 유치 향서 낸 강원도 춘천 경북 포항 전남 나주 곳 가운데 청주 나주 최종 배수 후보지 됐 습니다 허경재 충청북도 신 성장산업 국장 입지 조건 다는 거 전체 지자체 지원 사업 굉장히 짜임새 게 실현 가능 성 게 짜여져 다는 강조 습니다 심사 위원 수긍 분위기 였 판단 됩니다 충북 방사광 가속기 구축 정부 첫 사업 에서 경북 포항 고배 마신 뒤 만 도전 입니다 첫 실패 이후 입지 조건 검토 대응 전략 보완 부터 대 정부 활동 강화 만큼 최종 유치 습니다 바이오 반도체 관련 산업 인력 시설 몰려 지역 비해 수도 권 인접 해 다는 강조 습니다 빛 활용 해 물질 미세 현상 연구 시설 인 만큼 지질학 안정 돼 다는 강점 입니다 나주 지역 균형발전 논리 앞세우 가운데 최종 후보지 내일 청주 오창 나주 곳 현장 심사 뒤 가려집니다 기대 고용 창출 인원 만 만 조 가까운 생산 부가 가치 유발 효과 충북 순위 현안 공들여 온 사업 에서 결실 거둘지 관심 쏠리 습니다 진희정 입니다 진희정',
#  '청주 충청북도 코로나 침체 지역 경제 회복 백 억 투입 충북 형 뉴딜 사업 추진 합니다 이시종 지사 오늘 브리핑 에서 도내 각 시군 일자리 창출 지역 경제 활성 화 마을 주민 자율 결정 길 포장 하수도 정비 주차장 꽃길 조성 소 규모 지역 개발 사업 지원 밝혔 습니다 충청북도 동 단위 지역 억 이하 밖 소 규모 행정 구역 천만 이하 사업비 지원 계획 입니다 송근섭',
#  '대전 앵커 대 국회 출범 앞두 대 전시 지역구 국회의원 당선인 첫 정책 간담회 열 었 습니다 대 전시 현안 해결 위한 자리 였 민주당 대전 석 모두 차지 면서 지역 현안 해결 속도 붙 을지 주목 됩니다 보도 조정아 입니다 리포트 대전 시장 지역 국회의원 당선인 첫 정책 간담회 열 었 습니다 최대 화두 당선인 공약 바탕 지역 현안 해결 대 전시 특히 혁신 도시 지정 촉구 공공 기관 유치 도시 철도 호선 트램 건설 숙원 사업 해결 정치 권 협조 당부 습니다 허태정 대전 시장 대부분 공약 지역 발전 꼭 필요 저희 대 전시 민선 추진 고자 사업 내용 방향 상당 부분 일치 어서 스타트업 파크 조성 한국 형 바이오 랩 센트럴 구축 주요 사업 대한 내년도 국비 지원 함께 건의 습니다 당선인 최대한 협력 약속 습니다 박병석 민주당 대전 서구 갑 당선인 굵직 국책 사업 성공 유치 마무리 과제 저희 습니다 의원 님 허태정 시장 님 함께 한마음 한뜻 시민 뜻 부응 도록 최선 겠 습니다 포스트 코로나 시대 앞두 대비책 구체 화 해야 한다는 목소리 이어졌 습니다 조승래 민주당 대전 시당 위원장 대 전시 가진 여러 장점 포스트 코로나 시대 어떻게 대응 인가 대해서 당정 간 코 중심 대책 위 구체 구축 필요 겠 대 전시 대 국회 에서 시정 민주당 팀 본격 가동 면서 이전 비해 큰 성장 동력 확보 을지 주목 됩니다 조정 아입니다 조정아',
#  '대구경북 대학교 실험실 폭발 사고 피해 학생 가족 교수 학내 구성원 오늘 경북 대 본관 에서 회견 열 치료비 지원 재개 촉구 습니다 학교 측 즉각 치료비 지원 재개 재발 방지 위한 대책 마련 해야 한다고 주장 습니다 권기준',
#  '지난해 국회 에서 열린 조국 법무부 장관 후보 자 인사 청문회 에서 박지원 의원 조국 후보 자 딸 았 다는 표창장 사진 취재진 공개 연합뉴스 지난해 국회 에서 열린 조국 법무부 장관 후보 자 인사 청문회 에서 박지원 의원 조국 후보 자 딸 았 다는 표창장 사진 취재진 공개 연합뉴스 정경 심 동양 대 교수 측 딸 조모 동양 대 표창장 발급 경위 관련 해 최성 해 동양 대 총장 에게서 위임 발급 다는 기존 입장 뒤집 봉사상 줄 테 니 기안 올리 라는 최 총장 듣 표창장 발급 았 진술 알려졌 국민 일보 정 교수 측 지난 서울 중앙 지법 형사 부 임정엽 권성수 김선희 부장 판사 최 총장 딸 조 봉사상 줄 테 니 기안 해서 올리 정식 승인 정상 인 표창장 았 다는 취지 의견서 제출 보도 앞서 재판부 정 교수 측 피고인 위조 행위 관여 는지 대한 입장 전혀 다며 위조 관여 표창장 단순히 전달 인지 면 총장 직접 직인 찍 아도 어 학교 육 발급 다는 묵시 승낙 이나 전결 위임 규정 따라 피고인 직접 표창장 발급 다는 인지 입장 밝혀 달 요청 바 그간 최 총장 에게서 표창장 발급 권한 위임 주장 해 던 정 교수 측 이날 재판 에서 최 총장 기안 해서 올리 다며 그간 입장 주장 내세웠 정 교수 주장 최 총장 조 자기 명의 표창장 결재 해 준 증언 충돌 한다 최 총장 공판 증인 출석 해 명의 발급 된 정 교수 딸 아들 표창장 이나 수료증 수여 자체 진술 바 최 총장 딸 발급 된 최우수 봉사상 이름 된 표창장 총장 재직 동안 본 으며 개인 표창장 대해서 자세히 살펴보 딸 표창장 대한 결재 서류 본 한편 재판부 오후 시 까지 정 교수 대한 추가 구속 영장 발부 여부 결정 겠 밝혔 지난해 기소 된 정 교수 구속 기간 까지 따라서 재판부 추가 구속 영장 발부 결정 면 정 교수 자정 석방 된다 검찰 정 교수 구속 영장 포함 았 지만 기소 단계 에서 추가 된 미공개 정보 이용 차명 주식 거래 증거인 멸 교사 혐의 추가 구속 영장 발부 해 달 재판부 요청 반면 정 교수 측 헌법 정신 어긋나 별건 구속 라는 입장 정혜정 중앙일보',
#  '대구 국립 대구 과학관 코로나 생활 방역 전환 따라 오늘 부터 상설 전시관 엽 니 다재 개관 시설 상설 전시 관 미래형 자동차 체험 관 며 아이 플레이 관 영상관 천체 투 영관 열 습니다 과학관 이용객 대상 발열 검사 문진 표 작성 뒤 관람 허용 며 부분 개관 인 고려 해 이달 까지 입장료 는다고 밝혔 습니다 이하늬',
#  '랜드 제련소 생산 크루거 란 드 금화 랜드 제련소 홈피 캡처 재판매 랜드 제련소 생산 크루거 란 드 금화 랜드 제련소 홈피 캡처 재판매 랜드 제련소 생산 골드바 랜드 제련소 홈피 캡처 재판매 랜드 제련소 생산 골드바 랜드 제련소 홈피 캡처 재판매 요하네스버그 연합뉴스 김성진 특파원 남아프리카 공화국 랜드 제련소 신종 코로나 바이러스 감염증 코로나 생산 차질 빚 었 던 금 제련 공장 재가동 한다고 블룸버그 통신 보도 크루거 란 드 금화 금괴 생산 랜드 제련소 런던 금시장 협회 로부터 아프리카 에서 유일 게 인증 제련 업체 다프 라빈 베 이나스 최고 경영자 랜드 제련소 달 간 셧다운 끝 이번 공장 가동 한다고 랜드 제련소 지난 돌입 봉쇄 령 예외 대상 었 으나 용광로 폐쇄 근무자 줄이 제련 역량 줄였 요하네스버그 소재 제련소 생산 재개 스위스 제련소 생산 단계 별 증가 맞물려 요 시장 에서 극 엇갈렸 던 금값 관련 공급 우려 완화 보인다고 블룸버그 전망 랜드 제련소 코로나 사태 민간 항공사 통한 수송 어려워 자 아프리카 광산 에서 가공 금속 수송 거나 금괴 런던 보낼 전세기 이용 해 왔 랜드 제련소 앵글 골드 아샨티 하모니 골드 마이닝 금광 회사 금괴 제련 콩고 민주 공화국 탄자니아 일부 생산 업자 위해서 제련 해 런던 시장 판매 대행 해 왔 남아공 이달 부터 광산 활동 직원 까지 재가동 도록 허용 세계 최대 크롬 생산 국인 남아공 애 소어 크롬 광산 직원 코로나 양성 반응 보여 생산 잠정 중단 한다고 밝혔 로이터 통신 전했',
#  '대전 앵커 지난해 삼성 조 투자 계획 발표 이후 아산 배방 월천 지구 아산시 개발 축 급부상 습니다 당장 신혼 부부 위한 첫 충남 행복 주택 건설 함께 주거 상업시설 건축 모처럼 활기 띄 습니다 보도 최선중 입니다 리포트 아산 배방 월천 지구 중심 들어서 게 될 충남 행복 주택 준공 목표 터파 공사 한창 입니다 입주 뒤 자녀 낳 으면 임대료 아도 돼 벌써 하루 수십 건 씩 입주 문의 이어지 습니다 조상 숙공 인 중개사 관심 습니다 언제 입주 는지 조건 뭔지 왜냐면 이쪽 인프라 갖춰져 초중 고등학교 가까이 산업단지 가깝 뜨거운 관심 배방 월천 지구 건설 경기 전반 영향 습니다 지난 다목 체육관 들어선 어 장애 유아 비 장애 유아 함께 다니 통합 유치원 건립 속도 습니다 주거 상업 용지 인 전체 필지 가운데 필지 건축 인허가 신청 들어왔 건 공동 주택 공사 시작 됐 습니다 김홍진 산시 개발 정책 건축 시기 상황 고요 공동 주택 착공 시기 볼 주변 건축주 건축 행위 활발히 진행 습니다 특히 삼성 조 대 투자 예정 된 탕정 지구 인접 해 추가 개발 가능 성 높 습니다 산시 의회 전담 팀 꾸리 최적 주거지 인 부각 시켜 협력 업체 유치 계획 입니다 안정근 아산시 의원 삼성 대 규모 투자 맞물려서 일자리 창출 기업 유치 촉매제 역할 예상 됩니다 착공 이후 부지 매각 개발 더뎠 던 아산 배방 월천 지구 새로운 활기 찾 습니다 최선 입니다 최선중',
#  '대구 앵커 전국 코로나 확진 자 대구 에서 발생 는데요 방역 대응 오늘 부터 생활 방역 체제 전환 됐 지만 대구 에서 코로나 완전 종식 강화 된 방역 대책 시행 됩니다 정혜미 보도 합니다 리포트 대구 시내버스 정류장 버스 기다리 시민 모두 마스크 쓰 습니다 마스크 쓰 일상 화 됐 지만 차 확산 막 보다 강력 조치 취해 집니다 대구시 부터 전국 최초 대중교통 공공시설 에서 마스크 착용 의무 화 행정 명령 발동 합니다 어기 면 과태료 백만 부과 됩니다 코로나 방역 체제 생활 방역 본격 전환 됐 지만 처럼 대구 에서 정부 지침 보다 강화 된 방역 지침 시행 됩니다 권영진 대구 시장 대구 코 상황 전국 인 상황 달리 심하 생활 방역 전환 습니다 따라 도서관 미술관 공공시설 문 닫 감염병 취약 경로당 노인 복지 관 휴관 연장 됩니다 생활 방역 수칙 정부 수칙 보다 배 늘렸 습니다 특히 대구시 면역력 약한 아동 어린이집 아동 복지 센터 아동 곳 세분 화 해 생활 수칙 지침 장소 추가 습니다 어린이집 이달 까지 휴 어 초 고등학생 등교 추가 연장 될 예정 입니다 강은희 대구시 교육감 학생 교육부 지침 지만 나머지 초중 학생 대구 특수 상황 따라 격일 교와 부제 등교 시행 계획 입니다 감염 경로 확진 자 산발 발생 어 결코 안심 상황 대구 형 방역 코 뿌리 뽑 긴장 고삐 단단히 죄 습니다 정혜미 입니다 정혜미',
#  '대구 코로나 면역 폭풍 증상 위중 상태 였 던 대구 지역 대 환자 건강 회복 해 퇴원 습니다 경북대병원 남성 환자 여 간 집중 치료 끝 완치 돼 어젯밤 퇴원 밝혔 습니다 환자 지난 확진 판정 뒤 상태 악화 돼 인공 심폐 치료 까지 았 지만 최근 건강 회복 습니다 이종영',
# ...
#  '수원 뉴시스 김종택 수원여객 회 삿 돈 억 빼돌린 혐의 특정 경제 범죄 중처 벌 법상 횡령 구속 영장 청구 된 라임 자산 운용 환매 중단 사태 핵심 인물 김봉현 스타 모빌리티 회장 구속 피의자 심문 영장 실질 심사 오후 경기 수원 남부 경찰서 유치장 에서 수원 뉴시스 김종택 수원여객 회 삿 돈 억 빼돌린 혐의 특정 경제 범죄 중처 벌 법상 횡령 구속 영장 청구 된 라임 자산 운용 환매 중단 사태 핵심 인물 김봉현 스타 모빌리티 회장 구속 피의자 심문 영장 실질 심사 오후 경기 수원 남부 경찰서 유치장 에서 수원 뉴시스 이병희 경찰 라임 사태 핵심 인물 드러난 김봉현 스타 모빌리티 회장 여행 가방 은닉 해 온 억 현금 발견 해 압수 확인 됐 경기 남부 지방 경찰청 지능 범죄 수사대 김 회장 대한 수원여객 횡령 사건 수사 과정 에서 현금 억 상당 압수 밝혔 경찰 지난 김 회장 특정 경제 범죄 중처 벌 관한 법률 위반 횡령 혐의 검찰 송치 면서 압수 현금 같이 송치 김 회장 부터 지난해 까지 스타 모빌리티 이사 수원여객 재무 담당 전무 이사 공모 해 버스 업체 수원여객 운용 자금 억 빼돌린 혐의 김 회장 지난 월일 구속 영장 발부 됐 지만 도주 다가 지난달 오후 시 께 서울 성북구 빌라 에서 검거 됐 과정 에서 은신처 였 던 빌라 은닉 던 현금 억만 발견 됐 이후 경찰 김 회장 빼돌린 돈 대해 수사 다가 김 회장 돈 은닉 던 물품 보관 업체 찾아냈 여기 억 상당 만원 권 어 여행 용 가방 발견 돈 출처 대해 김 회장 재향군인회 상 조회 관련 해 빼돌린 돈 진술 알려졌 라임 으로부터 투자 자금 회사 투자 방식 수백 억 횡령 혐의 서울 남부 지검 에서 수사 스타 모빌리티 측 서울 남부 지검 김 회장 회 삿 돈 억 횡령 다며 고소 한편 김 회장 공모 해 수원여객 자금 횡령 지난달 구속 기소 됐 해외 도피 공감 언론 뉴시스',
#  '목포 뉴시스 서해 지방 해양 경찰청 사진 뉴시스 목포 뉴시스 서해 지방 해양 경찰청 사진 뉴시스 목포 뉴시스 박상수 문화재 보호 구역 에서 불법 조업 던 어선 해경 항공 순찰 적발 됐 다일 서해 해경 면 무안 항공대 지난 오전 시 께 전남 여수시 하백 해역 순찰 어선 척이 명승지 지정 된 백도 해상 떠 발견 항공대 즉시 항공기 장착 된 동영상 감시 카메라 통해 어선 불 법조 업 의심 됨 확인 인근 해역 경비 던 경비함 연락 해 단속 들어갔 단속 결과 고흥 선적 급 어선 인 호 선장 면허 소지 채 백도 접근 해 농어 포획 문화재 보호법 위반 혐의 적용 됐 여수 백도 문화재 보호법 의해 명승 호로 지정 돼 섬 인근 해상 이내 일반인 상륙 접근 동식물 포획 엄격 게 돼 어길 이하 징역 또는 만 이하 벌금 처해진 다서 해 해경 본격 인 레저 시즌 맞 해역 에서 불 법조 업 사전 차단 고정익 항공기 급 함정 이용 해 집중 단속 벌인다는 계획 강진홍 서해 청 항공 단장 이번 순찰 단속 투입 된 항공기 열 영상 카메라 장착 돼 야간 불 법조 업 대한 식별 가능 다며 어 족 자원 보호 항공기 활용 다양 활동 전개 겠 밝혔 공감 언론 뉴시스',
#  '전남 장성군 에서 방침 제조 다나 메디컬 대표 양판 정사진 지름 미소 안면 침 개발 발표 일본 에서 만 생산 던 지름 초 정밀 침 보다 머리카락 굵기 침 미소 안면 침 주로 얼굴 머리 시술 쓰인다 메디컬 측 얼굴 침 맞 고통 가장 큰 부위 인데 침 가늘 수록 피부 들어갈 고통 출혈 막 다며 침 끝 부분 로켓 모양 연마 해 시술 시 자극 거의 느낄 소개 동안 국내 에서 생산 된 방침 대부분 지름 였 일본 세린 사만 침 제조 해 세계 고부 가치 방침 시장 독점 해 왔 기존 침 보다 가격 배 이상 비싼 초 정밀 침 국내 기술 개발 해 수입 대체 효과 클 라는 게 회사 측 설명 회사 초 정밀 침 제조 침 자동 화 생산 기계 대의 제조 시설 모두 자체 개발 방침 침 본체 인 침체 침 손가락 잡 침병 이뤄진 다이 회사 침 생산 업체 처음 레이저 용접 이용 해 침체 침병 결합 침체 침병 합치 사출 방식 사용 업체 차별 화 꾀했 지름 스테인리스 스틸 철사 생산 국내 업체 로부터 철사 구매 해 자른 뒤 끝 뾰족 게 연마 핵심 기술 완벽 멸균 침 제조 산화에틸렌 가스 멸균 헤 파 필터 갖춘 클린 룸 에서 만 침 생산 한다 메디컬 이달 미소 안면 침 양산 시작 계획 장성 임동 률 한국 경제',
#  '건설 해수 담수화 파일럿 플랜트 건설 제공 건설 해수 담수화 파일럿 플랜트 건설 제공 서울 연합뉴스 홍 국기 건설 세계 처리 선진 시장 인 싱가포르 해수 담수화 신재 생 에너지 기술 상용 화 위한 공동 연구 들어갔 밝혔 기술 건설 국토 교통부 환경부 국책 연구 사업 통해 세계 최초 개발 성공 해수 담수화 플랜트 하수 이용 플랜트 에서 배 출수 이용 해 에너지 만드 이번 공동 연구 싱가포르 수자원 공사 측 건설 만 단독 제한 입찰자 자격 부여 연구 개발비 싱가포르 측 대부분 부담 파격 인 조건 연구 기간 이달 부터 까지 간 공동 연구 담수 플랜트 회사 인 니마 비롯 해 한국건설 기술 연구원 국민대 고려대 참여 다싱 가포르 수자원 부족 현재 해수 담수화 하수 이용 플랜트 전체 용수 수요량 약 공급 까지 늘릴 계획 어 이번 공동 연구 상당 공 들이 건설 소개 건설 기술 상용 화 면 처리 선진 시장 인 싱가포르 물론 세계 처리 시장 에서 독보 인 경쟁력 갖추 게 된다고 기대',
#  '경기도 시공사 사옥 전경 사진 제공 경기도 시공사 경기도 시공사 사옥 전경 사진 제공 경기도 시공사 경기도 시공사 기존 주택 매입 임대 사업 일환 도내 저소득층 청년층 주거 안정 가구 주택 대한 매도 신청 접수 시작 한다고 밝혔 경기도 시공사 기존 주택 매입 임대 사업 일환 도내 저소득층 청년층 주거 안정 가구 주택 대한 매도 신청 접수 시작 한다고 밝혔 매도 신청 대상 주택 매입 대상 지역 호당 전용 면적 이하 가구 주택 공동 주택 다세대 주택 연립 주택 도시 형 생활 주택 용 면적 이하 주거 용 오피스텔 며 공사 올해 총 호 매입 계획 매입 대상 대중교통 접근성 입지 여건 건물 노후 관리 주택 품질 검토 서류 심사 현장 심사 매입 심의 과정 거쳐 선정 한다 매입 가격 곳 감정평가 기관 평가 금액 산술 평균치 산정 감정평가 기관 매도 자 추천 가격 결정 공정 성 확보 토록 였 부터 까지 우편 만 접수 진행 한다 기존 주택 매입 임대 사업 공사 주택 매입 여 개보 후 생계 의료 급여 수급 자 부모 가족 장애 인 청년 소득 낮 무주택 서민 시세 수준 임대 사업 경기 김동우',
#  '부산 뉴시스 한국 여성 전화 전국 여성 시민 사회단체 오후 부산 연제구 부산 지방 법원 에서 성폭력 피해자 정당방위 인정 위한 재심 개시 촉구 회견 진행 이후 법원 재심 청구서 접수 밝혔 이번 재심 성폭행 시도 남성 혀 깨물 었 다가 가해자 몰려 유죄 선고 대 여성 만 정당방위 인정 해 줄 요구 며 청구 사진 한국 여성 전화 제공 공감 언론 뉴시스 독자 여러분 소중 제보 기다립니다 가치 화제 성 판단 사진 또는 영상 뉴시스 사진 영상 부 보내 시 면 적극 반영 겠 습니다',
#  '과학 기술 정보 통신부 한국연구재단 이달 과학 기술 인상 수상자 전헌수 서울대 물리 천 문학부 교수 사진 선정 교수 차세대 레이저 인 무작위 레이저 제어 기술 개발 해 나노 광학 지평 넓혔 다는 평가 았 이달 과학 기술 인상 우수 연구 성과 과학 기술 발전 공헌 연구자 준다 수상자 장관 상 상금 만 는다 한국 경제',
#  '종합 여행사 여행 박사 최근 주주 총회 열 양 주일 벅스 대표 사진 신임 대표 선임 밝혔 양 대표 입사 해 게임 제작 지원 그룹 장 센터 장 지냈 서비스 개발 랩 장 거쳐 티켓 링크 대표 역임 양 대표 음악 제공 서비스 인 벅스 여행 박사 대표 겸직 한다 한국 경제',
#  '충청남도 서산시 산업 용 보일러 제조 기업 인 대열 보일러 대표 신국호 비 엔에스 대표 장영순 기업 으로부터 억 규모 투자 유치 발표 기업 까지 서산 오토 밸리 산업단지 만 억 들여 공장 신축 한다 창업 대열 보일러 국내 산업 용 보일러 시장 점유 율 위 용량 큰 노통 연관식 보일러 부문 에선 국내 위 업체 비 엔에스 산업 용 보일러 방열기 제조 기업 조달청 우수 제품 생산 업체 지정 았 전국 산업 용 보일러 판매망 구축 해 운영 기업 공장 짓 제품 양산 들어가 면 억 생산 효과 억 부 가치 효과 발생 라는 게 설명 다홍 성 강태우 한국 경제',
#  '경기도 경제 과학 진흥 원경 과원 포스트 코로나 시대 대비 해 유튜브 통한 세계 시장 동향 영상 안내 강화 한다고 발표 도내 기업 수출 도우미 역할 경기 비즈니스 센터 소장 세계 각 지역 시장 동향 영상 제작 해 유튜브 제공 방식 중소기업 수출 지원 경과 미국 중국 러시아 말레이시아 해외 개국 곳 운영 세계 시장 동향 안내 영상 기존 분기 별 제작 지만 올해 부터 격월 변경 해 수출 기업 정보 제공 계획 경과 지난해 부터 중국 미국 베트남 국내 기업 수출 상위 개국 위주 시장 동향 제공 해 왔 올해 개국 외 인도 말레이시아 교역 량 증가 국가 시장 동향 영상 업로드 해 제공 중국 하반기 시장 동향 보상 성 소비 심리 수요 게 증가 전망 김 기려 중국 상하이 소장 영상 안내 통해 중국 여행 문화 뷰티 산업 분야 에서 소비 게 증가 전망 라며 도내 관련 기업 중국 시장 동향 예의 주시 필요 주문 수원 윤상연 한국 경제',
#  '김대권 대표 김대권 대표 인천 송도 국제 도시 바이오 업체 보로 노이 대표 김대권 김현태 비소 세포 성 폐암 치료제 독성 실험 다음 달 진행 뒤 내년 초 차 임상 실험 들어간다고 발표 독성 실험 신체 유해 다는 증명 임상 단계 과정 다비소 세포 성 폐암 신체 돌연변이 단백질 활동 면서 발병 암 일종 비흡연자 폐암 걸리 해당 된다 김대권 대표 비소 세포 성 폐암 서양 보다 동양 여성 자주 발병 며 한국 일본 중국 집중 돼 회사 개발 신약 후보 물질 돌연변이 단백질 억제 해 기능 폐암 유발 물질 선택 해서 억제 표적 치료제 돌연변이 단백질 뇌 전이 차단 다는 게 회사 측 설명 김 대표 비소 세포 성 폐암 환자 뇌 전이 돼 뇌 암 이어지 다며 뇌 이동하 돌연변이 세포 억제 폐암 인한 뇌 전이 막 준다고 설명 치료제 일반 항암 치료제 처럼 주사 투약 방식 라 하루 만 먹 경구 용 개발 된다 항암 치료 병원 방문 일상 생활 에서 폐암 치료 가능 게 특징 회사 체내 에서 과다 게 분비 면역 물질 억제 자 면역 표적 치료 제도 개발 면역 세포 과다 게 활동 면 정상 세포 죽이 부작용 아토피 피부염 류머티즘 관절염 궤양성 대장염 발병 자 면역 질환 유발 체내 신호 전달 물질 억제 차 임상 실험 지난 캐나다 식약청 신청 자 면역 질환 동양인 보다 서양인 많이 나타나 올해 차 임상 실험 거쳐 내년 제약 회사 기술 이전 추진 계획 다보 노이 회사 설립 후 체내 신호 전달 물질 차원 화학 물 데이터베이스 기반 플랫 폼 구축 직원 가운데 바이오 의약 화학 분자설 계 전문 연구 인력 김 대표 경구 용 항암제 자 면역 치료 표적 치료제 꾸준히 개발 해 글로벌 바이오 벤처 기업 성장 겠 인천 강준 완 한국 경제',
#  '박 의원 이번 꾸러미 대상자 미 인가 대안 학교 학생 포함 학교 밖 청소년 포함 았 아시아 경제 호남 취재 본부 이형권 순천시 의회 의장 서정진 박혜정 의원 제회 임시회 제차 본회의 에서 분 자유 발언 통해 학교 밖 청소년 대한 차별 지원 촉구 박 의원 지난달 농산물 어 택배 상자 았 다며 남도 전남 교육청 협업 해 도내 모든 학생 가정 만 상당 지역 농산물 보내 친환경 농산물 꾸러미 였 지난 제회 임시회 에서 분 자유 발언 통해 학교 밖 청소년 대한 지원 관심 촉구 듯이 코로나 라는 국가 재난 상황 에서 누구 보다 보살핌 필요 아이 학교 밖 청소년 강조 면서 학교 밖 청소년 제도 권 학생 똑같 대우 아야 한다며 어른 보살핌 아야 대상 임 잊 달 요청 한편 친환경 농산물 꾸러미 순천시 관 초 중고 학생 만 대상 신청 만 여 이미 발송 완료 미 신청 학생 대상 추가 신청 마감 될 예정 호남 취재 본부 이형권',
#  '국토 교통부 부터 전국 시도 에서 청년 신혼 부부 위한 매입 임대 주택 입주자 모집 한다고 오늘 밝혔 습니다 모집 물량 총 천 가구 청년 가구 신혼 부부 천 가구 수도 권 천 가구 지방 천 가구 공급 됩니다 이달 입주 신청 면 부터 입주 가능 합니다 청년 매입 임대 주택 취업 준비 이사 잦 청년 주거 특성 고려 해 에어컨 냉장고 세탁기 포함 풀 옵션 공급 며 시세 최대 까지 거주 습니다 다만 기존 계약자 동일 시 군구 신청 습니다 신혼 부부 매입 임대 주택 가구 주택 에서 시세 거주 유형 천 가구 아파트 오피스텔 에서 시세 거주 유형 천 가구 나뉘 어 공급 됩니다 신혼 부부 매입 임대 주택 개월 이상 미 입주 된 주택 가구 혼인 후 자녀 나이 만 세 까지 기준 완화 해 신혼 부부 기회 제공 합니다 다만 신 청시 인 가구 이전 다르 게 가구원 수별 가구 당 월평균 소득 인 만 인 만 인 만 적용 므로 소득 요건 충족 여부 확인 해야 합니다 입주 자격 자산 요건 입주 후 검증 해 신속 게 입주 으나 자산 요건 충족 밝혀 면 임대료 시세 인상 불 이익 습니다 자세 내용 이후 한국 토지 주택 공사 청약 센터 누리집 게시 된 공고문 마이 홈 콜 센터 통해 문의 습니다 국토 부 관계자 신종 코로나 바이러스 감염증 코로나 경제 활동 위축 된 청년 신혼 부부 주거 부담 없이 일상 돌아갈 도록 지속 공공 임대 주택 공급 해 나가 겠 습니다 온라인 팀',
#  '대전 김기태 장종태 대전 서구 청장 제회 어버이날 앞두 구 양묘장 에서 직접 재배 카네이션 관내 독거 노인 여 세대 노인 복지 시설 복지 관 개소 전달 대전 서구 제공 코리아',
#  '안동 시청 안동 시청 경북 안동시 권역 별 감염병 전문 병원 유치 나섰 현재 안동 풍산읍 경북 바이오 산업단지 바이오 사이언스 플 라즈 마 국내 최고 기술 개발 시스템 갖춘 백신 기업 연구 기관 인 국제 백신 연구소 안동 분원 경북 바이오산업 연구원 어서 으며 백신 제조 지원 생산 동물 세포 실증 지원 센터 완공 목표 건립 백신 기업 연구 시설 바탕 감염병 전문 병원 안동 들어설 국내 최고 백신 산업 메카 자리매김 다는 분석 권역 별 감염병 전문 병원 신종 감염병 확산 시 권역 환자 일시 격리 치료 위한 전문 의료 기관 재난 수준 감염병 위기 적극 대응 기관 전염병 전문 병원 안동 유치 가장 먼저 불 지핀 대 총선 김형동 당선인 김 당선인 이미 백신 관련 인프라 국내 최고 인 안동 지역 감염병 전문 병원 설립 지역 주민 종합 의료 서비스 제공 코 나와 재난 발생 시 감염병 대응 체계 중추 역할 수행 도록 해야 한다고 밝혔 박성수 동시 부시장 경북 도와 구체 협의 거쳐 안동 유치 힘 쏟 겠 다며 백신 관련 클러스터 갖춰진 안동 지역 감염병 전문 병원 유치 될 완벽 동물 바이러스 관련 시스템 갖추 게 된다고 엄 재진 매일신문',
#  '서울 과학 기술 대학교 총장 이동훈 설립 서울 과학 기술 대학교 기술 지주 대표 김종 선가 모태 펀드 차 출자 사업 교육부 대학 창업 펀드 운용 사 선정 었 교육부 부총리 겸 교육부 장관 유은혜 한국 벤처 투자 대표 이영민 서울 과학 기술 대학교 기술 지주 이하 서울 기대 기술 지주 충북 대학교 기술 지주 벤처 박스 주식회사 공동 운용 사 신청 모태 펀드 차 출자 사업 대학 창업 펀드 선정 었 발표 대학 창업 펀드 대학 창업 기업 초기 자금난 해소 정부 대학 함께 조성 펀드 로서 학생 교원 대학 초기 창업 기업 대한 투자 자금 지원 통해 대학 창업 생태 계 조성 창업 붐 확산 도모 목적 서울 기대 기술 지주 공동 운용 사 함께 투자액 최소 억 이상 조성 여 피 투자 기업 발굴 투자 집행 펀드 운용 전반 담당 게 며 투자 회수 시 성과 보수 지급 게 된다 서울 기대 기술 지주 김종선 대표 어 대학 창업 펀드 운용 사 선정 었 다며 펀드 결성 도록 지원 해 준 교육부 한국 벤처 투자 서울 과학 기술 대학교 감사 뜻 전하 였 대학 창업 펀드 운용 사 로써 책임 역할 강조 면서 서울 기대 기술 지주 피 투자 기업 발굴 육성 후속 지원 자체 개발 여 운영 단비 프로그램 적극 활용 겠 였 프로그램 통해 창업 인프라 교내 연구자 매칭 통한 기술 지원 피 투자 기업 제공 여 창업 초기 사업 성과 어 성공 인 투자 될 도록 밝혔 온라인 중앙일보 중앙일보',
#  '형제 복지 피해자 인 최승우 국회 의원 회관 캐노피 올라가 형제 복지 진상 규명 위한 과거 사법 제정 촉구 사진 민중 형제 복지 피해자 인 최승우 국회 의원 회관 캐노피 올라가 형제 복지 진상 규명 위한 과거 사법 제정 촉구 사진 민중 형제 복지 피해 생존자 최승우 농성 인 국회 의원 회관 모습 사진 노 지민 형제 복지 피해 생존자 최승우 농성 인 국회 의원 회관 모습 사진 노 지민 미디어 오늘 장슬기 대 국회 이달 끝 가운데 형제 복지 피해 생존자 단식 농성 시작 국회 계류 인 진실 화해 위한 과거 사정리 기본법 일부 개정 법률안 과거 사법 통과 해 달 라는 요구 에서 피해 생존자 최승우 지난 서울 여의도 국회 의원 회관 입구 지붕 캐노피 올라 단식 농성 시작 이날 최 피해 생존자 한종선 함께 과거 사법 과거 사법 발 이전 엔 형제 복지 특별법 통과 외치 며 국회 정문 에서 천 막 설치 해 노숙 농성 벌 인지 째 최 지난해 과거 사법 통과 외치 며 지하철 국회의사당역 출구 지붕 에서 고공 단식 농성 만 병원 실려갔 지만 여전히 법안 법제 사법 위원회 상정 조차 았 지난해 월일 국회 행정 안전 위원회 회의록 면 이날 자유 한국 당현 미래 통합 당 의원 참석 았 이날 홍익표 더불 어 민주당 의원 안건 조정 위원장 이채익 통합 당 행안 위 간사 님 통화 과거 사법 대해 불참 겠 다는 의사 통보 현실 마지막 까지 회의 참여 독려 된다면 찬성 의원 중심 표결 처리 밖에 한다고 야당 근거 과거 사법 통과 반대 지난해 월일 한국 당 행안 위원 여당 과거 사법 날치기 다며 회견 열 었 야당 상임위 에서 합의 된 법안 면 본 회의 에서 처리 겠 다는 방침 밝혔 이후 총선 여의도 일정 중단 됐 대 국회 시작 예정 피해 생존자 통합 당 관계자 전화 돌려 대 국회 에서 과거 사법 통과 해야 한다고 요청 그럼에도 희망 자 최 고공 단식 돌입 최 오후 미디어 오늘 통화 에서 이채익 간사 여러 차례 찾아갔 우호 방금 홍익표 의원 다녀갔 이채익 간사 합의 됐 더라 결국 당 지도부 과거 사법 반대 한다는 뜻 최 당 핵심 관계자 전화 다가 과거 사법 신경 쓴다는 답변 었 최 대통령 책임 추궁 문재인 대통령 피해 생존자 국회 에서 증언 대회 당시 야당 대표 자격 참석 해 형제 복지 관심 다며 사진 찍 뜻 함께 당시 부산 사상구 국회의원 었 전한 뒤 그런데 대통령 나서 형제 복지 단 차례 언급 았 비판 대통령 언급 면 분명 법안 처리 힘 실린다 최 민 식이 법 매우 중요 그런데 통과 다가 시민 토론 다가 대통령 언급 그래서 통과 됐 번방 관련 법 중요 이렇게 몇 만 통과 뒤 과거 사법 연기 기회 충분히 었 음 주장 국회 축 인 민주당 실망감 드러냈 이인영 민주당 원내대표 통 합당 원내대표 선출 면 본 회의 열 어 대 국회 유종 미 거둘 게 겠 면서 개헌 꺼냈 국민 개헌안 발의 이른바 국민 개헌 발안제 통과 겠 다는 지만 심재철 통합 당 원내대표 본회 개의 합의 다며 코로나 위기 무슨 개헌 논의 냐고 부정 최 시급 당정 청 나서 야 한다며 국가 폭력 피해자 길바닥 에서 죽 어 개헌 중요 냐고 비판 최 통과 돼야 내려갈 라며 게 거 라며 기다리 건 지쳤 가운데 최근 박인근 형제 복지 원장 직접 원생 폭행 살인 가담 다는 증언 나왔 박 원장 실에 고문 도구 다는 증언 었 과거 사법 행안 위 통과 함께 최근 형제 복지 기사 졌 최 언론 에서 대서특필 이것 순간 일지 모른다 너무 조용 게 흘러가 다며 시민 관심 호소 진실 힘 통일 재단 전국 단체 성명 패스트 트랙 통해 예산안 선거법 공 수처 법 소방법 추경 차례 국회 본회의 통과 다며 오로지 과거 사법 만 뒷전 밀려난 대 국회 에서 과거 사법 통과 해야 한다고 주장 또한 민주당 민생 당 정의당 일부 의원 관련 단체 이날 회견 열 통합 당 이번 국회 에서 과거 사법 통과 적극 참여 촉구 관련 기사 변한 게 으니 형제 복지 피해자 국회 농성 관련 기사 형제 복지 모두 외면 던 지옥 장슬기',
#  '대전시 이달 까지 지역 대학 정부 출연 연구소 대상 기술 이전 사업 화 희망 우수 기술 모집 한다 모집 분야 정보 통신 기술 바이오 혁신 기술 분야 시 최종 선발 된 기술 전문 경영인 매칭 하고 투자자 초기 투 자금 조달 방식 창업 유도 계획 한국 경제',
#  '킨텍스 제공 킨텍스 제공 킨 텍스 제공 킨텍스 제공 해외 코 상황 따라 전시회 해외 바이어 참가 제한 고려 해 화상 상담 장비 일체 주최 측 지원 함 으로써 참가 업체 국내외 판로 개척 위한 상담 원활 게 이뤄질 도록 준비 밝혔 국내 최대 규모 전시 컨벤션 센터 인 킨텍스 정부 신종 코로나 바이러스 감염증 코로나 방역 체계 생활 거리 생활 방역 전환 됨 따라 코로나 확산 방지 지역 감염 예방 정부 지침 준 특별 방역 실시 비상 상황실 설치 적극 인 방역 대응책 마련 해 시행 밝혔 킨텍스 부터 개최 건축 박람회 행사 앞두 킨텍스 시장 단계 출입 통제 전시장 외부 소독 방역 외부 공기 유입 공조 시행 코로나 확산 예방 최선 전시회 성공 인 개최 직접 전시회장 방문 바이어 참가 업체 원격 상담 지원 화상 상담 시스템 도입 다방면 한국 전시 업계 새로운 출발 위한 노력 킨텍스 전시회 개최 주최자 공조 해 단계 걸쳐 시장 출입 통제 시행 계획 먼저 단계 해당 전시장 출입구 유증 상자 전시장 출입 제한 최소 화 해 운영 된다 기본 마스크 미착용 자 시장 출입 제한 며 전시장 출입구 소독 매트 열화상 카메라 안면 인식 체온계 설치 어 유증 상자 발생 시 출입 제지 상시 대기 인 구급차 이용 여 인근 선별 진료소 백 병원 이송 후 검사 도록 조치 계획 단계 전시 홀 출입구 에서 차 체온 측정 실시 며 손 소독 제 사용 비닐장갑 착용 이후 입장 가능 게 된다 입장객 접촉 최소 화 입장 대기 줄 로비 바닥 간격 유지 선 표시 예정 며 로비 주요 동선 상 안내 용 배 너 설치 여 참 관객 코로나 감염 예방법 안내 계획 단계 인 전시 홀 내부 상시 순찰 자 통해 마스크 비닐장갑 착용 의무 화 예정 며 전시회 참가 업체 근무자 카페테리아 직원 안면 전체 커버 안면 보호 대 착용 게 된다 또한 전시 홀 부스 간격 이상 이격 일방통행 유도 통해 불 필요 접촉 최소 화 함께 상담 회장 카페테리아 아크릴 차 단막 별도 설치 출구 착용 비닐장갑 폐기 위한 방역 폐기물 수거 함 비치 될 예정 다전 시장 단계 출입 통제 함께 외부 전문 방역 업체 통해 회 시장 외부 특별 방역 소독 작업 진행 된다 특별 방역 외 킨텍스 자체 인력 활용 해 전시장 입구 화장실 흡연 부스 에스컬레이터 로비 의자 관람객 출입 주요 구역 관람객 손 닿 모든 곳 일반 방역 작업 철저 게 진행 예정 며 실내 공기 통한 감염 가능 성 최소 화 평소 유지 던 외부 공기 유입 률 최대한 높여 내부 공조 시행 깨끗 실내 공기 유지 감염 위험 성 제거 최선 겠 다는 방침 킨텍스 관계자 국내 최 대전 시장 인 킨텍스 에서 개최 행사 전하 게 치러질 도록 관할 보건소 주최 측 긴밀 협조 관계 구축 철저 방역 시스템 마련 함 으로써 킨텍스 코로나 상황 전시회 개최 모범 사례 될 도록 최선 겠 다며 고양 박재구 국민 일보',
#  '동영상 소나무 치명 인 선충 병 피해 적극 인 방제 지난해 보다 감소 나타났 습니다 산림청 전국 에서 발생 소나무 선충 병 피해 고사목 감염 우려 목 만 그루 제거 함 따라 만 그루 이상 피해 나타난 지역 지자체 줄 었 밝혔 습니다 소나무 선충 제주 경상도 중심 피해 극심 충남 에서 최근 서산 에서 피해 발생 습니다 무 단복 제',
#  '삼 척 시청 사진 삼 척 시청 제공 삼척 시청 사진 삼 척 시청 제공 삼 척 뉴시스 장경일 인턴 강원 삼척시 신종 코로나 바이러스 감염증 코로나 사태 따라 부터 시민 인 당 재난 긴급 생활 비 만 지급 한다 대상 월일 기준 삼척시 주민 등록 된 시민 만 여 삼척 사랑 상품권 지급 된다 기준일 이후 타 시군 전출자 사망자 외국인 삼척시 의원 삼척시 급 이상 공무원 제외 된다 삼척시 코로나 장기 화 어려움 겪 시민 생활 안정 지역 경제 활성 화 마을 별 배부 전담반 편성 해 차 삼척시 재난 지원금 까지 직접 지급 한다 차 미지급 된 재난 지원금 일월 주소지 읍 면 동 행정 복지 센터 방문 해 직접 수령 면 된다 재난 지원금 까지 사용 해야 한다 공감 언론 뉴시스',
#  '동영상 앵커 천 물류 화재 참사 관련 해 정부 해당 시공사 대한 특별 감독 나섰 습니다 이번 참사 교훈 삼 화재 취약 곳 는지 전국 여 건설 현장 긴급 점검 습니다 이승훈 보도 입니다 특별 감독 곳 천 물류 창고 원청 시공사 인 건우 입니다 천 현장 뿐 라 건우 본사 건우 시공 물류 냉동 창고 모두 조사 합니다 화재 위험 큰 곳 환기 제때 는지 용접 불티 튀 건 관리 는지 조목조목 살필 예정 입니다 바뀐 산업 안전 보건 법 원청 사업자 책임 게 묻 습니다 이른바 김용균 법 천 화재 책임 따지 겠 다는 겁니다 박화진 고용 노동부 고용 정책 실장 원청 본사 대해서 안전 관리 체계 현장 지원 적정 성 여부 확인 원청 시공 인 건설 현장 건설 현장 대해서 원청 안전 보건 조치 의무 이행 여부 집중 감독 계획 입니다 별도 전국 건설 현장 대한 긴급 감독 진행 합니다 공정 절반 이상 진행 된 곳 부터 먼저 점검 합니다 보통 공정 넘 으면 용접 외장 작업 게 그때 부터 화재 위험 커집니다 확실히 따져 노동자 안전 가볍 게 업체 도록 겠 다는 게 정부 약속 입니다 하지만 노동 계 징벌 손해 배상 담 중대 재해 기업 처벌 법 어야 원청 사업자 정신 차릴 거 주장 습니다 이승훈 입니다 당신 제보 됩니다 여러분 소중 제보 기다립니다 검색 해 채널 추가 전화 메일 온라인 제보 권 자',
#  '포항 뉴시스 강진구 이강덕 포항시장 오전 시청 에서 간담회 열 어 지난 일간 시행 해 왔 던 거리 두기 끝내 이날 부터 생활 거리 전환 함 따라 선제 차별 화 된 실천 운동 지침 대해 발표 며 시민 적극 인 동참 당부 사진 포항시 제공 포항 뉴시스 강진구 이강덕 포항시장 오전 시청 에서 간담회 열 어 지난 일간 시행 해 왔 던 거리 두기 끝내 이날 부터 생활 거리 전환 함 따라 선제 차별 화 된 실천 운동 지침 대해 발표 며 시민 적극 인 동참 당부 사진 포항시 제공 포항 뉴시스 강진구 경북 포항시 지난 일간 시행 해 왔 던 거리 두기 끝내 부터 생활 거리 전환 함 따라 선제 차별 화 된 실천 운동 지침 대해 발표 시민 적극 인 동참 당부 한다고 밝혔 이강덕 포항시장 이날 포항 형 생활 거리 지역 감염 원천 차단 시민 긴급 재난 지원금 신속 지급 학생 안심 등교 환경 조성 세부 방안 대책 대해 설명 우선 포항 형 생활 거리 두기 관련 튼튼 방역 기초 위 경제 활동 병행 기치 개인 집단 철저 위생 관리 기본 인 거리 지속 전제 공공시설 운영 단계 재개 포스트 코로나 대응 전략 마련 해 일상 회복 통한 통합 경제 활력 민생 안정 도모 해 나가 또한 아프 면 빨리 선별 진료소 언제 어디 서 마스크 착용 일상 화 초 손 씻 옷소매 기침 안심 식사 매너 지키 사이 팔 간격 건강 거리 두기 매일 이상 환기 주기 소독 거리 멀 어 져도 마음 가까이 개인 방역 대 기본 생활 수칙 발표 준 당부 범 시민 대책 회의 기관 단체 별 범 시민 실천 운동 펼치 비롯 일자리 생활 방역 단과 방역 컨설팅 단의 운영 함께 매주 수요일 진행 일제 방역 날 다중 이용 시설 집중 방역 지속 실시 사례 별 위생 수칙 담 홍보 영상 함께 해요 포항 생활 백신 통한 지속 인 대 시민 홍보 펼쳐 나가 긴급 재난 지원금 지난 현금 지원 대상자 대한 지급 우선 완료 나머지 대상자 대한 신속 지급 지난 부터 전담 팀 구성 운영 시민 일상 회복 지원 모든 행정력 동원 저소득층 시 생활 지원 긴급 복지 지원 아동 양 육 시 지원 재난 긴급 생활비 지원 노인 일자리 사업 활동비 지자체 에서 지원 각종 지원 비 지급 마무리 예정 부터 단계 시작 개학 관련 부터 상황 종료 시점 까지 학교 개학 지원 단 운영 학교 인 전담 공무 원명 지정 해 학생 안심 등교 환경 전력 쏟 방침 지역 타 지역 출신 학생 밀집 일부 학교 대한 특별 관리 함께 부터 까지 개학 학교 시설 대한 사전 점검 개학 당일 등교 현장 점검 나서 이강덕 포항시장 생활 거리 전환 해서 감염병 대한 경각심 느슨 해져서 며 오히려 방역 지속 면서 감염병 확산 차단 일상 경제 활동 병행 해 나가 야 라며 개학 관련 교육 지원 청과 긴밀 협력 통해 모든 가능 성 대한 예방 대책 갖추 준비 만전 기하 겠 공감 언론 뉴시스',
#  '성관 계 영상 유포 혐의 경찰 수사 종근당 이장한 회장 장남 이번 음주운전 혐의 재판 넘겨졌 습니다 서울 중앙 지방 검찰청 지난달 음주운전 혐의 모 불 구속 상태 에서 재판 넘겼 습니다 지난 서울 강남 에서 술 취한 채 차 다가 경찰 발견 돼 입건 됐 습니다 당시 혈중 알코올 농도 면허 취소 수준 었 던 확인 됐 습니다 별개 경찰 여성 명과 각각 성관계 영상 몰래 찍 어 트위터 올린 혐의 조사 습니다 앞서 경찰 체포 해 구속 영장 신청 지만 법원 에서 기각 됐 현재 보강 수사 진행 입니다 당신 제보 됩니다 여러분 소중 제보 기다립니다 검색 해 채널 추가 전화 메일 온라인 제보 권 자',
#  '강원 동해시 무릉 계곡 건설 인 베틀 바위 등산 점검 현장 사진 동해 시청 제공 강원 동해시 무릉 계곡 건설 인 베틀 바위 등산 점검 현장 사진 동해 시청 제공 동해 뉴시스 장경일 인턴 강원 동해시 시장 심규 언 무릉 계곡 베틀 바위 등산 총 구간 현재 까지 공정 률 무릉 계곡 매표소 베틀 바위 구간 대해 산림 생태 계 전문가 합동 현장 점검 실시 동해시 동부 지방 산림청 공동 산림 사업 협약 맺 베틀 바위 전경 일반 공개 사업비 억만 들여 이후 완공 목표 공사 현장 점검 결과 토대 탐방객 안전 최우선 시설물 확충 회양목 군 락지 생태 계 보존 주요 구간 대한 안전 보호 대책 보완 예정 장애 인 일자리 사업 확대 추진 강원 동해시 시장 심규 언 장애 인 능력 적성 맞 근로 연계 통한 자활 자립 지원 지난 부터 장애 인 일자리 사업 확대 추진 밝혔 이번 확대 추진 당초 에서 늘어난 총 동 행정 복지 센터 복지 시설 행정 도우미 장애 인 전용주 차 구역 관리 행복 나눔 냉장고 관리 다양 분야 에서 근무 한다 올해 장애 인 일자리 사업 신종 코로나 바이러스 감염증 지난 일부 휴업 했으나 부터 모든 사업 정상 추진 매달 둘째 수요일 문화 날 지속 운영 강원 동해시 시장 심규 언 롯데시네마 동해 관 협약 해 매월 둘째 수요일 동해 시 문화 날 지속 운영 한다고 밝혔 동해시 문화 날 동해시 롯데시네마 동해 관 협의 통해 매월 둘째 수요일 영화 관람료 성인 청소년 할인 해 영화 관람 날 공감 언론 뉴시스',
#  '청주 맹석 제조 업체 경기 실사 지수 추이 사진 충북 본부 제공 제조 업체 경기 실사 지수 추이 사진 충북 본부 제공 코로나 여파 충북 지역 제조 업체 기업 경기 이후 최저치 기록 한국은행 충북 본부 조사 결과 충북 지역 제조업 업 황 실사 지수 전달 보다 하락 다음 달 업 황전 망실 사지 수도 전달 보다 떨어졌 이후 최저치 코로나 영향 심각 조사 됐 비 제조업 업 황도 다음 달 업 황 전망 게 부진 나타났 제조 업체 경영 애 사항 불 확실 경제 상황 비중 가장 높 내수 부진 인력난 인 건 비 상승 순 었 비 제조 업체 내수 부진 비중 가장 높 불 확실 경제 상황 인력난 인 건 비 상승 순 었 권 자 노컷뉴스',
#  '청주 최범규 사진 자료 사진 사진 자료 사진 현직 경찰관 아내 흉기 수차례 찔려 병원 신세 진 뒤늦 게 알려졌 경찰 면 도내 모 파출소 소속 경위 지난달 오전 시 쯤 청주시 율량동 자택 에서 아내 여 휘두른 흉기 목 수차례 찔렸 신고 출동 경찰 현장 에서 붙잡 살인 미수 구속 해 기소 의견 검찰 넘겼 병원 옮겨져 치료 으며 다행히 생명 지장 알려졌 경찰 관계자 가정 사건 인 관계 자세 내용 알려 줄 권 자 노컷뉴스',
#  '경기도 올 수원 컨벤션 센터 에서 열리 경기 환경 산업 참가 기업 까지 모집 한다 산업 탄소 제로 시대 위한 미래 환경 산업 새로운 방향 모색 마련 됐 경기 환경 산업 사무국 연락 거나 홈페이지 에서 내용 확인 조기 신청 기업 참 가비 할인 해 준다 한국 경제',
#  '광주시 전라남도 이달 까지 광주 전남 합동 온라인 일자리 박람회 연다 기업 구직자 간 연결 취업 포털 잡 코리아 진행 한다 채 용관 운영 기업 채용 공고 등록 구직자 이력서 등록 인적 성 검사 이뤄진 한국 경제',
#  ...]

# %%
stopwords = ['에','는','은','을','했','에게','있','이','의','하','한','다','과','때문','할','수','무단','따른','및','금지','전재','경향신문','기자','는데','가','등','들','파이낸셜','저작','등','뉴스']

# %%
stopwords.extend(['카카오톡', '재', '배포', '도', '아', '씨', '로', '고', '를',
                  '로', '것', '으로', '다고', '라고', '으로', '와', '로', '위해', '기', '놓', '잘', '좀', '개', '어떻', '어떤', '가지'])

# %%
stopwords
# Out:
# ['에',
#  '는',
#  '은',
#  '을',
#  '했',
#  '에게',
#  '있',
#  '이',
#  '의',
#  '하',
#  '한',
#  '다',
#  '과',
#  '때문',
#  '할',
#  '수',
#  '무단',
#  '따른',
#  '및',
#  '금지',
#  '전재',
#  '경향신문',
#  '기자',
#  '는데',
#  '가',
#  '등',
#  '들',
#  '파이낸셜',
#  '저작',
#  '등',
#  '뉴스',
#  '카카오톡',
#  '재',
#  '배포',
#  '도',
#  '아',
#  '씨',
#  '로',
#  '고',
#  '를',
#  '로',
#  '것',
#  '으로',
#  '다고',
#  '라고',
#  '으로',
#  '와',
#  '로',
#  '위해',
#  '기',
#  '놓',
#  '잘',
#  '좀',
#  '개',
#  '어떻',
#  '어떤',
#  '가지']

# %%
def preprocessing(data):
  text_data = []

  for sentence in data:
    temp_data = []
    #- 토큰화
    temp_data = tokenizer.morphs(sentence) 
    #- 불용어 제거
    temp_data = [word for word in temp_data if not word in stopwords] 
    text_data.append(temp_data)

  text_data = list(map(' '.join, text_data))

  return text_data

# %%
import time
start = time.time()
text_data= preprocessing(df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 주 시 일 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 주 시민 받 긴급 재난 지원금 인 이상 가구 기준 만 원 받 게 되 며 인 가구 만 원 인 가구 만 원 인 가구 만 원 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 다른 이유 국비 지방비 부담 비율 다파 주 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 원 지급 어 시민 국비 지원금 만 지급 며 인 가구 기준 총 지원 금액 파주시 재난 기본소득 만 원 경기도 재난 기본소득 만 원 정부 긴급 재난 지원금 만 원 총 만 원 받 게 된다 취약 계층 아닌 시민 오 월일 부터 소지 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 주 시 일 김정기 부시장 단장 긴급 재난 지원금 추진 태 스 크 포스 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자
# time : 5.373556137084961

# %%
X_train, X_test, y_train, y_test = train_test_split(text_data, df['code'], random_state = 0)

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
def tfidf_vectorizer(data):
  data_counts = count_vect.transform(data)
  data_tfidf = tfidf_transformer.transform(data_counts)
  return data_tfidf

# %%
y_pred= clf.predict(tfidf_vectorizer(X_test))
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.90      0.74      0.81       236
#           사회       0.79      0.91      0.85       422
#        생활/문화       0.81      0.77      0.79       341
#
#     accuracy                           0.82       999
#    macro avg       0.83      0.80      0.82       999
# weighted avg       0.82      0.82      0.82       999

# %% [markdown]
# ### 불용어를 20개 정도 추가했을때는 큰 드라마틱한 변화는 없고 단순 f1-score 평균이 1% 올랐다.

# %%
words_txt_path = os.getenv("HOME") + "/aiffel/news_crawler/한국어불용어100.txt"
stopwords_100 = pd.read_table(words_txt_path)
stopwords_100['이'] = new_stopwords

# %%
new_stopwords = list(new_stopwords)

# %%
stopwords.extend(new_stopwords)
stopwords.extend('한다')

# %%
words2_txt_path = os.getenv("HOME") + "/aiffel/news_crawler/stopwords-ko.txt"
stopwords_2 = pd.read_table(words2_txt_path)

# %%
stopwords.extend(stopwords_2)

# %%
import time
start = time.time()
text_data= preprocessing(df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 시 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 시민 긴급 재난 지원금 인 이상 가구 기준 만 게 며 인 가구 만 인 가구 만 인 가구 만 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 이유 국비 지방비 부담 비율 다파 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 지급 어 시민 국비 지원금 만 지급 며 인 가구 기준 총 지원 금액 파주시 재난 기본소득 만 경기도 재난 기본소득 만 정부 긴급 재난 지원금 만 총 만 게 된다 취약 계층 아닌 시민 월일 부터 소지 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 시 김정기 부시장 단장 긴급 재난 지원금 추진 태 스 포스 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자
# time : 6.116743803024292

# %%
X_train, X_test, y_train, y_test = train_test_split(text_data, df['code'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

def tfidf_vectorizer(data):
  data_counts = count_vect.transform(data)
  data_tfidf = tfidf_transformer.transform(data_counts)
  return data_tfidf

y_pred= clf.predict(tfidf_vectorizer(X_test))
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.90      0.75      0.81       236
#           사회       0.79      0.91      0.85       422
#        생활/문화       0.82      0.76      0.79       341
#
#     accuracy                           0.82       999
#    macro avg       0.83      0.81      0.82       999
# weighted avg       0.82      0.82      0.82       999

# %% [markdown]
# ### 불용어를 많이 추가해 정확도와 f1 score를 늘리려고 헀지만 여전히 변화가 미흡했다.

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터셋 추가하기

# %%
csv_path = os.getenv("HOME") + "/aiffel/news_crawler/news_data2.csv"
df2 = pd.read_table(csv_path, sep=',')
df2.head()
df2['news'] = df2['news'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
df2['news']
df2.drop_duplicates(subset=['news'], inplace=True)
idx = df2[df2['code'] == '경제'].index
df3 =df2.drop(idx)
print(df3.groupby('code').size().reset_index(name = 'count'))
# Out:
#     code  count
# 0  IT/과학    235
# 1     사회    554
# 2  생활/문화    446

# %%
new_df= pd.concat([df, df3])
new_df
# Out:
#                                                    news   code
# 0     파주시청 사진제공파주시 파주시청 사진제공파주시파주파이낸셜뉴스 강근주 기자 파주시는 ...     사회
# 1     동영상 뉴스이천 물류창고 화재 발화지점으로 지목된 지하 층에서 산소절단기의 산소 공...     사회
# 2     황범순 의정부시 부시장 을지대학교 의정부캠퍼스 및 부속병원 공사현장 안전점검 사진제...     사회
# 3     귀갓길 여성을 쫓아가 성범죄를 시도한 대 남성이 구속됐습니다서울 강남경찰서는 강간상...     사회
# 4     서울연합뉴스 대한약사회가 일부터 코로나바이러스 감염증 대응 체계를 사회적 거리두기에...     사회
# ...                                                 ...    ...
# 3194  레고켐바이오사이언스대표 김용주사진가 글로벌 기술수출에 또다시 성공했다 년 중국 포순...  IT/과학
# 3195  제대 국회의원선거 기간 중단됐던 네이버 실시간 급상승 검색어 서비스가 일 오후 시부...  IT/과학
# 3196  아마존 연합뉴스 자료사진 아마존 연합뉴스 자료사진직원들 코로나 확산 방지 조치 충분...  IT/과학
# 3197  제대 국회의원선거가 임박한 가운데 투표 및 개표 방송을 준비하는 기업들의 움직임이 ...  IT/과학
# 3198  롤 점검이 일 진행될 예정이다온라인게임 리그오브레전드이하 롤은 일 오전 시부터 오전...  IT/과학
#
# [5229 rows x 2 columns]

# %%
import time
start = time.time()
text_data = preprocessing(new_df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 시 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 시민 긴급 재난 지원금 인 이상 가구 기준 만 게 며 인 가구 만 인 가구 만 인 가구 만 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 이유 국비 지방비 부담 비율 다파 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 지급 어 시민 국비 지원금 만 지급 며 인 가구 기준 총 지원 금액 파주시 재난 기본소득 만 경기도 재난 기본소득 만 정부 긴급 재난 지원금 만 총 만 게 된다 취약 계층 아닌 시민 월일 부터 소지 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 시 김정기 부시장 단장 긴급 재난 지원금 추진 태 스 포스 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자
# time : 8.32047724723816

# %%
X_train, X_test, y_train, y_test = train_test_split(text_data, new_df['code'], random_state = 0)

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
def tfidf_vectorizer(data):
  data_counts = count_vect.transform(data)
  data_tfidf = tfidf_transformer.transform(data_counts)
  return data_tfidf

# %%
y_pred= clf.predict(tfidf_vectorizer(X_test))
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.90      0.72      0.80       285
#           사회       0.79      0.93      0.85       547
#        생활/문화       0.84      0.77      0.80       476
#
#     accuracy                           0.82      1308
#    macro avg       0.84      0.81      0.82      1308
# weighted avg       0.83      0.82      0.82      1308

# %% [markdown]
# ### 노션에 올라온 데이터를 추가했지만 그다지 변한 것이 없었다.. 하지만 이때 떠오른 건 가위바위보 게임이었다. 가위바위보 게임에서 내가 얻은 결론은 일단 데이터를 많이 확보해서 정확도를 늘려보자였다. 그래서 나는 크롤링을 통해 데이터셋의 크기를 늘렸다.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup


def make_urllist(page_num, code, date): 
  urllist= []
  for i in range(1, page_num + 1):
    url = 'https://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1='+str(code)+'&date='+str(date)+'&page='+str(i)   
    news = requests.get(url)

    
    soup = BeautifulSoup(news.content, 'html.parser')

    
    news_list = soup.select('.newsflash_body .type06_headline li dl')
   
    news_list.extend(soup.select('.newsflash_body .type06 li dl'))
        
    for line in news_list:
        urllist.append(line.a.get('href'))
  return urllist

# %%
from newspaper import Article
idx2word = {'101' : '경제', '102' : '사회', '103' : '생활/문화', '105' : 'IT/과학'}
.
def make_data(urllist, code):
  text_list = []
  for url in urllist:
    article = Article(url, language='ko')
    article.download()
    article.parse()
    text_list.append(article.text)


  df = pd.DataFrame({'news': text_list})


  df['code'] = idx2word[str(code)]
  return df

# %%
def make_total_data(page_num, code_list, date):
  df = None

  for code in code_list:
    url_list = make_urllist(page_num, code, date)
    df_temp = make_data(url_list, code)
    print(str(code)+'번 코드에 대한 데이터를 만들었습니다.')

    if df is not None:
      df = pd.concat([df, df_temp])
    else:
      df = df_temp

  return df

# %%
code_list = [102, 103, 105]

# %%
df_4 = make_total_data(10, code_list, 20200504)
# Out:
# 102번 코드에 대한 데이터를 만들었습니다.
# 103번 코드에 대한 데이터를 만들었습니다.
# 105번 코드에 대한 데이터를 만들었습니다.

# %%
import os

csv_path = os.getenv("HOME") + "/aiffel/news_crawler/news_data_3.csv"
df_4.to_csv(csv_path, index=False)

if os.path.exists(csv_path):
  print('{} File Saved!'.format(csv_path))
# Out:
# /home/aiffel0038/aiffel/news_crawler/news_data_3.csv File Saved!

# %%
csv_path = os.getenv("HOME") + "/aiffel/news_crawler/news_data_3.csv"
df4 = pd.read_table(csv_path, sep=',')
df4.head()
df4['news'] = df4['news'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
df4['news']
df4.drop_duplicates(subset=['news'], inplace=True)
print(df4.groupby('code').size().reset_index(name = 'count'))
# Out:
#     code  count
# 0  IT/과학    198
# 1     사회    191
# 2  생활/문화    189

# %%
new_df_2 = pd.concat([new_df, df4])

# %%
import time
start = time.time()
text_data = preprocessing(new_df_2['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 시 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 시민 긴급 재난 지원금 인 이상 가구 기준 만 게 며 인 가구 만 인 가구 만 인 가구 만 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 이유 국비 지방비 부담 비율 다파 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 지급 어 시민 국비 지원금 만 지급 며 인 가구 기준 총 지원 금액 파주시 재난 기본소득 만 경기도 재난 기본소득 만 정부 긴급 재난 지원금 만 총 만 게 된다 취약 계층 아닌 시민 월일 부터 소지 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 시 김정기 부시장 단장 긴급 재난 지원금 추진 태 스 포스 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자
# time : 8.494166135787964

# %%
X_train, X_test, y_train, y_test = train_test_split(text_data, new_df_2['code'], random_state = 0)

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
y_pred= clf.predict(tfidf_vectorizer(X_test))
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.88      0.78      0.83       331
#           사회       0.84      0.92      0.87       595
#        생활/문화       0.84      0.81      0.82       526
#
#     accuracy                           0.85      1452
#    macro avg       0.85      0.84      0.84      1452
# weighted avg       0.85      0.85      0.85      1452

# %% [markdown]
# ### 데이터셋을 늘리니 획기적으로 정확도가 2%가 올랐다. 역시.. 데이터셋 크기를 늘려주는 것이 매우 중요하다는 것을 다시금 깨달았다.

# %% [markdown]
# ---

# %% [markdown]
# ## 부록: 데이터셋을 늘리지 않고 단순히 모델을 바꾼다면 어떻게 변화할까?

# %%
import time
start = time.time()
text_data= preprocessing(df['news'])
print(text_data[0])
print("time :", time.time() - start)
# Out:
# 파주 시청 사진제 공파 주시 파주 시청 사진 제공 파주시 파주 강근주 파 시 관내 취약 계층 만 가구 대해 정부 긴급 재난 지원금 입금 완료 다파 시민 긴급 재난 지원금 인 이상 가구 기준 만 게 며 인 가구 만 인 가구 만 인 가구 만 정부 발표 긴급 재난 지원금 파주 시민 지급 금액 이유 국비 지방비 부담 비율 다파 시 이미 모든 시민 경기도 파주시 재난 기본 소득 인 당 각 만 지급 어 시민 국비 지원금 만 지급 며 인 가구 기준 총 지원 금액 파주시 재난 기본소득 만 경기도 재난 기본소득 만 정부 긴급 재난 지원금 만 총 만 게 된다 취약 계층 아닌 시민 월일 부터 소지 신용 체크카드 사 홈페이지 에서 긴급 재난 지원금 지원 신청 세대주 가족 지원금 일괄 신청 해야 한다 한편 파 시 김정기 부시장 단장 긴급 재난 지원금 추진 태 스 포스 구성 해 긴급 재난 지원금 원활 게 지급 될 도록 지원 한다 권 자
# time : 7.241555213928223

# %%
X_train, X_test, y_train, y_test = train_test_split(text_data, df['code'], random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = RandomForestClassifier().fit(X_train_tfidf, y_train)

# %%
y_pred= clf.predict(tfidf_vectorizer(X_test))
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.86      0.83      0.84       236
#           사회       0.85      0.89      0.87       422
#        생활/문화       0.83      0.79      0.81       341
#
#     accuracy                           0.84       999
#    macro avg       0.84      0.84      0.84       999
# weighted avg       0.84      0.84      0.84       999

# %%
from sklearn.linear_model import SGDClassifier
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_tran데이터를sform(X_train_counts)

clf = SGDClassifier().fit(X_train_tfidf, y_train)

# %%
y_pred= clf.predict(tfidf_vectorizer(X_test))
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.88      0.86      0.87       236
#           사회       0.90      0.88      0.89       422
#        생활/문화       0.83      0.86      0.84       341
#
#     accuracy                           0.87       999
#    macro avg       0.87      0.87      0.87       999
# weighted avg       0.87      0.87      0.87       999

# %% [markdown]
# ### 모델을 바꾸게 되는 것 또한 데이터셋을 늘려주는 효과를 나타났다.
